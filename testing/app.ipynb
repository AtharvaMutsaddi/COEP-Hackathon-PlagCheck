# %% [markdown]
# # Imports & Set up:

# %%
# %pip install -r ../requirements.txt
# Out:
# Collecting scikit-learn (from -r ../requirements.txt (line 1))
#   Downloading scikit_learn-1.4.1.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting sentence-transformers (from -r ../requirements.txt (line 2))
#   Using cached sentence_transformers-2.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting simhash (from -r ../requirements.txt (line 3))
#   Using cached simhash-2.1.2-py3-none-any.whl.metadata (382 bytes)
# Collecting langchain (from -r ../requirements.txt (line 4))
#   Using cached langchain-0.1.14-py3-none-any.whl.metadata (13 kB)
# Collecting pandas (from -r ../requirements.txt (line 5))
#   Downloading pandas-2.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting streamlit (from -r ../requirements.txt (line 6))
#   Downloading streamlit-1.33.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting python-Levenshtein (from -r ../requirements.txt (line 7))
#   Using cached python_Levenshtein-0.25.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting numpy<2.0,>=1.19.5 (from scikit-learn->-r ../requirements.txt (line 1))
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting scipy>=1.6.0 (from scikit-learn->-r ../requirements.txt (line 1))
#   Downloading scipy-1.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.6 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn->-r ../requirements.txt (line 1))
#   Downloading joblib-1.4.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->-r ../requirements.txt (line 1))
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl.metadata (13 kB)
# Collecting transformers<5.0.0,>=4.32.0 (from sentence-transformers->-r ../requirements.txt (line 2))
#   Using cached transformers-4.39.3-py3-none-any.whl.metadata (134 kB)
# Collecting tqdm (from sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.3 MB/s eta 0:00:00
# Collecting torch>=1.11.0 (from sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading torch-2.2.2-cp312-cp312-manylinux1_x86_64.whl.metadata (25 kB)
# Collecting huggingface-hub>=0.15.1 (from sentence-transformers->-r ../requirements.txt (line 2))
#   Using cached huggingface_hub-0.22.2-py3-none-any.whl.metadata (12 kB)
# Collecting Pillow (from sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading pillow-10.3.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting PyYAML>=5.3 (from langchain->-r ../requirements.txt (line 4))
#   Downloading PyYAML-6.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain->-r ../requirements.txt (line 4))
#   Downloading SQLAlchemy-2.0.29-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain->-r ../requirements.txt (line 4))
#   Downloading aiohttp-3.9.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain->-r ../requirements.txt (line 4))
#   Using cached dataclasses_json-0.6.4-py3-none-any.whl.metadata (25 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain->-r ../requirements.txt (line 4))
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-community<0.1,>=0.0.30 (from langchain->-r ../requirements.txt (line 4))
#   Using cached langchain_community-0.0.31-py3-none-any.whl.metadata (8.4 kB)
# Collecting langchain-core<0.2.0,>=0.1.37 (from langchain->-r ../requirements.txt (line 4))
#   Using cached langchain_core-0.1.40-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain->-r ../requirements.txt (line 4))
#   Using cached langchain_text_splitters-0.0.1-py3-none-any.whl.metadata (2.0 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain->-r ../requirements.txt (line 4))
#   Using cached langsmith-0.1.41-py3-none-any.whl.metadata (13 kB)
# Collecting pydantic<3,>=1 (from langchain->-r ../requirements.txt (line 4))
#   Downloading pydantic-2.6.4-py3-none-any.whl.metadata (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.1/85.1 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Collecting requests<3,>=2 (from langchain->-r ../requirements.txt (line 4))
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain->-r ../requirements.txt (line 4))
#   Using cached tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/bhushan/anaconda3/envs/new/lib/python3.12/site-packages (from pandas->-r ../requirements.txt (line 5)) (2.9.0)
# Collecting pytz>=2020.1 (from pandas->-r ../requirements.txt (line 5))
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->-r ../requirements.txt (line 5))
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting altair<6,>=4.0 (from streamlit->-r ../requirements.txt (line 6))
#   Downloading altair-5.3.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit->-r ../requirements.txt (line 6))
#   Using cached blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting cachetools<6,>=4.0 (from streamlit->-r ../requirements.txt (line 6))
#   Downloading cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting click<9,>=7.0 (from streamlit->-r ../requirements.txt (line 6))
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=16.8 in /home/bhushan/anaconda3/envs/new/lib/python3.12/site-packages (from streamlit->-r ../requirements.txt (line 6)) (24.0)
# Collecting protobuf<5,>=3.20 (from streamlit->-r ../requirements.txt (line 6))
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting pyarrow>=7.0 (from streamlit->-r ../requirements.txt (line 6))
#   Downloading pyarrow-15.0.2-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting rich<14,>=10.14.0 (from streamlit->-r ../requirements.txt (line 6))
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting toml<2,>=0.10.1 (from streamlit->-r ../requirements.txt (line 6))
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /home/bhushan/anaconda3/envs/new/lib/python3.12/site-packages (from streamlit->-r ../requirements.txt (line 6)) (4.11.0)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit->-r ../requirements.txt (line 6))
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->-r ../requirements.txt (line 6))
#   Using cached pydeck-0.8.1b0-py2.py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/bhushan/anaconda3/envs/new/lib/python3.12/site-packages (from streamlit->-r ../requirements.txt (line 6)) (6.4)
# Collecting watchdog>=2.1.5 (from streamlit->-r ../requirements.txt (line 6))
#   Downloading watchdog-4.0.0-py3-none-manylinux2014_x86_64.whl.metadata (37 kB)
# Collecting Levenshtein==0.25.1 (from python-Levenshtein->-r ../requirements.txt (line 7))
#   Downloading Levenshtein-0.25.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting rapidfuzz<4.0.0,>=3.8.0 (from Levenshtein==0.25.1->python-Levenshtein->-r ../requirements.txt (line 7))
#   Downloading rapidfuzz-3.8.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain->-r ../requirements.txt (line 4))
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain->-r ../requirements.txt (line 4))
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain->-r ../requirements.txt (line 4))
#   Downloading frozenlist-1.4.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain->-r ../requirements.txt (line 4))
#   Downloading multidict-6.0.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain->-r ../requirements.txt (line 4))
#   Downloading yarl-1.9.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting jinja2 (from altair<6,>=4.0->streamlit->-r ../requirements.txt (line 6))
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit->-r ../requirements.txt (line 6))
#   Downloading jsonschema-4.21.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting toolz (from altair<6,>=4.0->streamlit->-r ../requirements.txt (line 6))
#   Downloading toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain->-r ../requirements.txt (line 4))
#   Using cached marshmallow-3.21.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain->-r ../requirements.txt (line 4))
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r ../requirements.txt (line 6))
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting filelock (from huggingface-hub>=0.15.1->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading filelock-3.13.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.15.1->sentence-transformers->-r ../requirements.txt (line 2))
#   Using cached fsspec-2024.3.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain->-r ../requirements.txt (line 4))
#   Using cached jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting packaging<25,>=16.8 (from streamlit->-r ../requirements.txt (line 6))
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain->-r ../requirements.txt (line 4))
#   Downloading orjson-3.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.9 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1->langchain->-r ../requirements.txt (line 4))
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.16.3 (from pydantic<3,>=1->langchain->-r ../requirements.txt (line 4))
#   Downloading pydantic_core-2.16.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: six>=1.5 in /home/bhushan/anaconda3/envs/new/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->-r ../requirements.txt (line 5)) (1.16.0)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2->langchain->-r ../requirements.txt (line 4))
#   Downloading charset_normalizer-3.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2->langchain->-r ../requirements.txt (line 4))
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->langchain->-r ../requirements.txt (line 4))
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2->langchain->-r ../requirements.txt (line 4))
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit->-r ../requirements.txt (line 6))
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/bhushan/anaconda3/envs/new/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit->-r ../requirements.txt (line 6)) (2.17.2)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain->-r ../requirements.txt (line 4))
#   Downloading greenlet-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting sympy (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.32.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading regex-2023.12.25-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.0 MB/s eta 0:00:00
# Collecting tokenizers<0.19,>=0.14 (from transformers<5.0.0,>=4.32.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading tokenizers-0.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.32.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading safetensors-0.4.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r ../requirements.txt (line 6))
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->altair<6,>=4.0->streamlit->-r ../requirements.txt (line 6))
#   Downloading MarkupSafe-2.1.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r ../requirements.txt (line 6))
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r ../requirements.txt (line 6))
#   Downloading referencing-0.34.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r ../requirements.txt (line 6))
#   Downloading rpds_py-0.18.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r ../requirements.txt (line 6))
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain->-r ../requirements.txt (line 4))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting mpmath>=0.19 (from sympy->torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 2))
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading scikit_learn-1.4.1.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 12.7 MB/s eta 0:00:0000:0100:01
# Using cached sentence_transformers-2.6.1-py3-none-any.whl (163 kB)
# Using cached simhash-2.1.2-py3-none-any.whl (4.7 kB)
# Using cached langchain-0.1.14-py3-none-any.whl (812 kB)
# Downloading pandas-2.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB
pandas, nvidia-cusparse-cu12, nvidia-cudnn-cu12, marshmallow, markdown-it-py, Levenshtein, jsonpatch, jinja2, gitdb, aiosignal, scikit-learn, rich, python-Levenshtein, pydeck, nvidia-cusolver-cu12, langsmith, jsonschema-specifications, huggingface-hub, gitpython, dataclasses-json, aiohttp, torch, tokenizers, langchain-core, jsonschema, transformers, langchain-text-splitters, langchain-community, altair, streamlit, sentence-transformers, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed Levenshtein-0.25.1 MarkupSafe-2.1.5 Pillow-10.3.0 PyYAML-6.0.1 SQLAlchemy-2.0.29 aiohttp-3.9.3 aiosignal-1.3.1 altair-5.3.0 annotated-types-0.6.0 attrs-23.2.0 blinker-1.7.0 cachetools-5.3.3 certifi-2024.2.2 charset-normalizer-3.3.2 click-8.1.7 dataclasses-json-0.6.4 filelock-3.13.3 frozenlist-1.4.1 fsspec-2024.3.1 gitdb-4.0.11 gitpython-3.1.43 greenlet-3.0.3 huggingface-hub-0.22.2 idna-3.6 jinja2-3.1.3 joblib-1.4.0 jsonpatch-1.33 jsonpointer-2.4 jsonschema-4.21.1 jsonschema-specifications-2023.12.1 langchain-0.1.14 langchain-community-0.0.31 langchain-core-0.1.40 langchain-text-splitters-0.0.1 langsmith-0.1.41 markdown-it-py-3.0.0 marshmallow-3.21.1 mdurl-0.1.2 mpmath-1.3.0 multidict-6.0.5 mypy-extensions-1.0.0 networkx-3.3 numpy-1.26.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 orjson-3.10.0 packaging-23.2 pandas-2.2.1 protobuf-4.25.3 pyarrow-15.0.2 pydantic-2.6.4 pydantic-core-2.16.3 pydeck-0.8.1b0 python-Levenshtein-0.25.1 pytz-2024.1 rapidfuzz-3.8.1 referencing-0.34.0 regex-2023.12.25 requests-2.31.0 rich-13.7.1 rpds-py-0.18.0 safetensors-0.4.2 scikit-learn-1.4.1.post1 scipy-1.13.0 sentence-transformers-2.6.1 simhash-2.1.2 smmap-5.0.1 streamlit-1.33.0 sympy-1.12 tenacity-8.2.3 threadpoolctl-3.4.0 tokenizers-0.15.2 toml-0.10.2 toolz-0.12.1 torch-2.2.2 tqdm-4.66.2 transformers-4.39.3 typing-inspect-0.9.0 tzdata-2024.1 urllib3-2.2.1 watchdog-4.0.0 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.embeddings import HuggingFaceInferenceAPIEmbeddings

# %%
inference_api_key="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"

# %%
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# %%
embeddings_model = HuggingFaceInferenceAPIEmbeddings(
    api_key=inference_api_key, model_name="sentence-transformers/all-mpnet-base-v2"
)

# %%
def calculate_similarity_matrix(vectors):
    return cosine_similarity(vectors)

def print_sim_scores_for_all(data,cosine_similarity_mat):
    entries=[]
    i=0
    while(i<len(data)):
        j=0
        while(j<len(data)):
            if i !=j:
                entries.append([data[i],data[j],cosine_similarity_mat[i][j]])         
            j+=1
        i+=1
        
    df=pd.DataFrame(entries)
    df.columns=["text1","text2","sim score"]
    return df

# %%
prog1 = """
#include<stdio.h>
#include<stdlib.h>
int main(){
    int a = 0;
    int n = 10; // Define the value of n
    for(int i = 0; i < n; i++){
        a += i;
    }
    return a;
}
"""

prog2 = """
#include<stdio.h>
#include<stdlib.h>
int main(){
    int ans = 1;
    int n = 10; // Define the value of n
    for(int i = 0; i < n; i++){
        ans *= ans;
    }
    if(ans % 2){
        ans = 1;
    }
    else{
        ans = 4; // Fixed the syntax error (missing semicolon)
    }
    return ans;
}
"""
prog3="""
// Shell.

#include "types.h"
#include "user.h"
#include "fcntl.h"

// Parsed command representation
#define EXEC  1
#define REDIR 2
#define PIPE  3
#define LIST  4
#define BACK  5

#define MAXARGS 10

struct cmd {
  int type;
};

struct execcmd {
  int type;
  char *argv[MAXARGS];
  char *eargv[MAXARGS];
};

struct redircmd {
  int type;
  struct cmd *cmd;
  char *file;
  char *efile;
  int mode;
  int fd;
};

struct pipecmd {
  int type;
  struct cmd *left;
  struct cmd *right;
};

struct listcmd {
  int type;
  struct cmd *left;
  struct cmd *right;
};

struct backcmd {
  int type;
  struct cmd *cmd;
};

int fork1(void);  // Fork but panics on failure.
void panic(char*);
struct cmd *parsecmd(char*);

// Execute cmd.  Never returns.
void
runcmd(struct cmd *cmd)
{
  int p[2];
  struct backcmd *bcmd;
  struct execcmd *ecmd;
  struct listcmd *lcmd;
  struct pipecmd *pcmd;
  struct redircmd *rcmd;

  if(cmd == 0)
    exit();

  switch(cmd->type){
  default:
    panic("runcmd");

  case EXEC:
    ecmd = (struct execcmd*)cmd;
    if(ecmd->argv[0] == 0)
      exit();
    exec(ecmd->argv[0], ecmd->argv);
    printf(2, "exec %s failed\n", ecmd->argv[0]);
    break;

  case REDIR:
    rcmd = (struct redircmd*)cmd;
    close(rcmd->fd);
    if(open(rcmd->file, rcmd->mode) < 0){
      printf(2, "open %s failed\n", rcmd->file);
      exit();
    }
    runcmd(rcmd->cmd);
    break;

  case LIST:
    lcmd = (struct listcmd*)cmd;
    if(fork1() == 0)
      runcmd(lcmd->left);
    wait();
    runcmd(lcmd->right);
    break;

  case PIPE:
    pcmd = (struct pipecmd*)cmd;
    if(pipe(p) < 0)
      panic("pipe");
    if(fork1() == 0){
      close(1);
      dup(p[1]);
      close(p[0]);
      close(p[1]);
      runcmd(pcmd->left);
    }
    if(fork1() == 0){
      close(0);
      dup(p[0]);
      close(p[0]);
      close(p[1]);
      runcmd(pcmd->right);
    }
    close(p[0]);
    close(p[1]);
    wait();
    wait();
    break;

  case BACK:
    bcmd = (struct backcmd*)cmd;
    if(fork1() == 0)
      runcmd(bcmd->cmd);
    break;
  }
  exit();
}

int
getcmd(char *buf, int nbuf)
{
  printf(2, "$ ");
  memset(buf, 0, nbuf);
  gets(buf, nbuf);
  if(buf[0] == 0) // EOF
    return -1;
  return 0;
}

int
main(void)
{
  static char buf[100];
  int fd;

  // Ensure that three file descriptors are open.
  while((fd = open("console", O_RDWR)) >= 0){
    if(fd >= 3){
      close(fd);
      break;
    }
  }

  // Read and run input commands.
  while(getcmd(buf, sizeof(buf)) >= 0){
    if(buf[0] == 'c' && buf[1] == 'd' && buf[2] == ' '){
      // Chdir must be called by the parent, not the child.
      buf[strlen(buf)-1] = 0;  // chop \n
      if(chdir(buf+3) < 0)
        printf(2, "cannot cd %s\n", buf+3);
      continue;
    }
    if(fork1() == 0)
      runcmd(parsecmd(buf));
    wait();
  }
  exit();
}

void
panic(char *s)
{
  printf(2, "%s\n", s);
  exit();
}

int
fork1(void)
{
  int pid;

  pid = fork();
  if(pid == -1)
    panic("fork");
  return pid;
}

//PAGEBREAK!
// Constructors

struct cmd*
execcmd(void)
{
  struct execcmd *cmd;

  cmd = malloc(sizeof(*cmd));
  memset(cmd, 0, sizeof(*cmd));
  cmd->type = EXEC;
  return (struct cmd*)cmd;
}

struct cmd*
redircmd(struct cmd *subcmd, char *file, char *efile, int mode, int fd)
{
  struct redircmd *cmd;

  cmd = malloc(sizeof(*cmd));
  memset(cmd, 0, sizeof(*cmd));
  cmd->type = REDIR;
  cmd->cmd = subcmd;
  cmd->file = file;
  cmd->efile = efile;
  cmd->mode = mode;
  cmd->fd = fd;
  return (struct cmd*)cmd;
}

struct cmd*
pipecmd(struct cmd *left, struct cmd *right)
{
  struct pipecmd *cmd;

  cmd = malloc(sizeof(*cmd));
  memset(cmd, 0, sizeof(*cmd));
  cmd->type = PIPE;
  cmd->left = left;
  cmd->right = right;
  return (struct cmd*)cmd;
}

struct cmd*
listcmd(struct cmd *left, struct cmd *right)
{
  struct listcmd *cmd;

  cmd = malloc(sizeof(*cmd));
  memset(cmd, 0, sizeof(*cmd));
  cmd->type = LIST;
  cmd->left = left;
  cmd->right = right;
  return (struct cmd*)cmd;
}

struct cmd*
backcmd(struct cmd *subcmd)
{
  struct backcmd *cmd;

  cmd = malloc(sizeof(*cmd));
  memset(cmd, 0, sizeof(*cmd));
  cmd->type = BACK;
  cmd->cmd = subcmd;
  return (struct cmd*)cmd;
}
//PAGEBREAK!
// Parsing

char whitespace[] = " \t\r\n\v";
char symbols[] = "<|>&;()";

int
gettoken(char **ps, char *es, char **q, char **eq)
{
  char *s;
  int ret;

  s = *ps;
  while(s < es && strchr(whitespace, *s))
    s++;
  if(q)
    *q = s;
  ret = *s;
  switch(*s){
  case 0:
    break;
  case '|':
  case '(':
  case ')':
  case ';':
  case '&':
  case '<':
    s++;
    break;
  case '>':
    s++;
    if(*s == '>'){
      ret = '+';
      s++;
    }
    break;
  default:
    ret = 'a';
    while(s < es && !strchr(whitespace, *s) && !strchr(symbols, *s))
      s++;
    break;
  }
  if(eq)
    *eq = s;

  while(s < es && strchr(whitespace, *s))
    s++;
  *ps = s;
  return ret;
}

int
peek(char **ps, char *es, char *toks)
{
  char *s;

  s = *ps;
  while(s < es && strchr(whitespace, *s))
    s++;
  *ps = s;
  return *s && strchr(toks, *s);
}

struct cmd *parseline(char**, char*);
struct cmd *parsepipe(char**, char*);
struct cmd *parseexec(char**, char*);
struct cmd *nulterminate(struct cmd*);

struct cmd*
parsecmd(char *s)
{
  char *es;
  struct cmd *cmd;

  es = s + strlen(s);
  cmd = parseline(&s, es);
  peek(&s, es, "");
  if(s != es){
    printf(2, "leftovers: %s\n", s);
    panic("syntax");
  }
  nulterminate(cmd);
  return cmd;
}

struct cmd*
parseline(char **ps, char *es)
{
  struct cmd *cmd;

  cmd = parsepipe(ps, es);
  while(peek(ps, es, "&")){
    gettoken(ps, es, 0, 0);
    cmd = backcmd(cmd);
  }
  if(peek(ps, es, ";")){
    gettoken(ps, es, 0, 0);
    cmd = listcmd(cmd, parseline(ps, es));
  }
  return cmd;
}

struct cmd*
parsepipe(char **ps, char *es)
{
  struct cmd *cmd;

  cmd = parseexec(ps, es);
  if(peek(ps, es, "|")){
    gettoken(ps, es, 0, 0);
    cmd = pipecmd(cmd, parsepipe(ps, es));
  }
  return cmd;
}

struct cmd*
parseredirs(struct cmd *cmd, char **ps, char *es)
{
  int tok;
  char *q, *eq;

  while(peek(ps, es, "<>")){
    tok = gettoken(ps, es, 0, 0);
    if(gettoken(ps, es, &q, &eq) != 'a')
      panic("missing file for redirection");
    switch(tok){
    case '<':
      cmd = redircmd(cmd, q, eq, O_RDONLY, 0);
      break;
    case '>':
      cmd = redircmd(cmd, q, eq, O_WRONLY|O_CREATE, 1);
      break;
    case '+':  // >>
      cmd = redircmd(cmd, q, eq, O_WRONLY|O_CREATE, 1);
      break;
    }
  }
  return cmd;
}

struct cmd*
parseblock(char **ps, char *es)
{
  struct cmd *cmd;

  if(!peek(ps, es, "("))
    panic("parseblock");
  gettoken(ps, es, 0, 0);
  cmd = parseline(ps, es);
  if(!peek(ps, es, ")"))
    panic("syntax - missing )");
  gettoken(ps, es, 0, 0);
  cmd = parseredirs(cmd, ps, es);
  return cmd;
}

struct cmd*
parseexec(char **ps, char *es)
{
  char *q, *eq;
  int tok, argc;
  struct execcmd *cmd;
  struct cmd *ret;

  if(peek(ps, es, "("))
    return parseblock(ps, es);

  ret = execcmd();
  cmd = (struct execcmd*)ret;

  argc = 0;
  ret = parseredirs(ret, ps, es);
  while(!peek(ps, es, "|)&;")){
    if((tok=gettoken(ps, es, &q, &eq)) == 0)
      break;
    if(tok != 'a')
      panic("syntax");
    cmd->argv[argc] = q;
    cmd->eargv[argc] = eq;
    argc++;
    if(argc >= MAXARGS)
      panic("too many args");
    ret = parseredirs(ret, ps, es);
  }
  cmd->argv[argc] = 0;
  cmd->eargv[argc] = 0;
  return ret;
}

// NUL-terminate all the counted strings.
struct cmd*
nulterminate(struct cmd *cmd)
{
  int i;
  struct backcmd *bcmd;
  struct execcmd *ecmd;
  struct listcmd *lcmd;
  struct pipecmd *pcmd;
  struct redircmd *rcmd;

  if(cmd == 0)
    return 0;

  switch(cmd->type){
  case EXEC:
    ecmd = (struct execcmd*)cmd;
    for(i=0; ecmd->argv[i]; i++)
      *ecmd->eargv[i] = 0;
    break;

  case REDIR:
    rcmd = (struct redircmd*)cmd;
    nulterminate(rcmd->cmd);
    *rcmd->efile = 0;
    break;

  case PIPE:
    pcmd = (struct pipecmd*)cmd;
    nulterminate(pcmd->left);
    nulterminate(pcmd->right);
    break;

  case LIST:
    lcmd = (struct listcmd*)cmd;
    nulterminate(lcmd->left);
    nulterminate(lcmd->right);
    break;

  case BACK:
    bcmd = (struct backcmd*)cmd;
    nulterminate(bcmd->cmd);
    break;
  }
  return cmd;
}
"""
prog4="""
#include<stdio.h>
#include<stdlib.h>
#include<unistd.h>
#include<string.h>
#define MAX_SIZE 512
#define MAX_ARGS 100 // Im setting max arguments that can be passe to the bash cmd
#define MAX_PATHS 20 // setting the number of paths to search for executables for

char **interpret_cmd(char *cmd) {
	char * ip=strdup(cmd);
    int arg_cnt = 0;
    char **args = (char **)malloc((MAX_ARGS + 1) * sizeof(char*)); // +1 as the last index contains null
    if (!args) {
        perror("Heap Memory Allocation");
        exit(EXIT_FAILURE);
    }
    int in_quotes = 0;  // tracking whether the current position is inside double quotes
    char *token = ip; 
    while (*ip && arg_cnt < MAX_ARGS) {
        if (*ip == ' ' && !in_quotes) {
            *ip = '\0';  // copied whole token
            if(strlen(token)>0){
                args[arg_cnt++] = strdup(token);
            }
            token = ip + 1;
        } else if (*ip == '"') {
            in_quotes = !in_quotes;
            if (!in_quotes) {
                *ip = '\0';  // copied whole token
                args[arg_cnt++] = strdup(token + 1);  // +1 to skip the opening quote
                token = ip + 1;
            }
        }
        ip++;
    }
    // in the end if ip becomes null there is chance that token has not been appended yet as there is no space in the end
    if (*token) {
        args[arg_cnt++] = strdup(token);
    }
    args[arg_cnt] = NULL;
    return args;
}
char ** get_paths(char * PATH){
	int path_cnt=0;
	char ** paths=(char**)malloc((MAX_PATHS+1)*sizeof(char*));
	char * path_cpy=strdup(PATH);
	if(!path_cpy || !paths){
		perror("Heap Memory Allocation");
        exit(EXIT_FAILURE);
	}
	char * path=strtok(path_cpy,":");
	while(path && path_cnt<MAX_PATHS){
		paths[path_cnt]=strdup(path);
		strcat(paths[path_cnt],"/");
		path_cnt+=1;
		path=strtok(NULL,":");
	}
	free(path_cpy);
	paths[path_cnt]=NULL;
	return paths;
}
char * is_cmd_set_path(char * ip){
    const char *str_identifier = "PATH=";
	char *buf = (char *)malloc(MAX_SIZE);
	if(strlen(ip)<=5){
		return NULL; // command must of size>=6
	}
    if (buf == NULL) {
        perror("Heap Memory Allocation");
        exit(EXIT_FAILURE);
    }
	for(int i=0;i<strlen(ip);i++){
		buf[i]=ip[i];
		if(i<5){
			if(buf[i]!=str_identifier[i]){
				free(buf);
				return NULL; // returning this tells us that its not a PATH set command 
			}
		}
	}
	return buf; // else we will return the whole ip command to set the path
}
char * is_cd(char * cmd){
	char * cmd_cpy=strdup(cmd);
	char * main_cmd=strtok(cmd_cpy," ");
	if(strcmp(main_cmd,"cd")==0){
		char * path=strtok(NULL," ");
		return path;
	}
	return NULL;
}
char * is_set_PS1(char * cmd){
	char * cmd_cpy=strdup(cmd);
	char * ps1_cmd=strtok(cmd_cpy,"=");
	if(ps1_cmd==NULL || strcmp(ps1_cmd,"PS1")!=0){
		return NULL;
	}
	return strtok(NULL,"=");
}
char * remove_spaces(char *str)
{
	char *trimmed_string=(char *)malloc(sizeof(char)*MAX_SIZE);
    int i = 0, j, k = 0;
    while (i<strlen(str) && (str[i] == ' ' || str[i] == '\t'))
    {
        i++;
    }
    for (j = i; str[j] != '\0' && !(str[i] == ' ' || str[i] == '\t'); j++)
    {
        trimmed_string[k] = str[j];
        k++;
    }
    trimmed_string[k] = '\0';
    return trimmed_string;
}
enum Redirection_Mode {input,output};

char* is_io_redirect(char * cmd,enum Redirection_Mode io_mode){
	char * delimitter;
	if(io_mode==input){
		delimitter="<";
	}else{
		delimitter=">";
	}
	char * const * args=interpret_cmd(cmd);
	for(int i=0;args[i]!=NULL;i++){
		if((strcmp(args[i],delimitter)==0)){
			return args[i+1];
		}
	}
	return NULL;
}
char* get_effective_ip(char * ip) {
	char ** strings=interpret_cmd(ip);
    int total_length = 0;
    int redirect_found = 0;    
    // finding how much size the final concetenated string should be
    for (int i = 0; strings[i] != NULL; ++i) {
        total_length += strlen(strings[i]) + 1; // +1 for space between strings
        if ((strcmp(strings[i],">")==0) || (strcmp(strings[i],"<")==0)) {
            redirect_found = 1;
            break;
        }
    }
    char *result = (char *)malloc(total_length);
    if (!result) {
        perror("Heap Memory Allocation");
        exit(EXIT_FAILURE);
    }

    // Concatenate strings until redirection symbol is encountered
    int offset = 0;
    for (int i = 0; strings[i] != NULL; ++i) {
        if ((strcmp(strings[i],">")==0) || (strcmp(strings[i],"<")==0)) {
            break;
        }
        if (i > 0) {
            strcat(result, " "); 
            offset++;
        }
        strcat(result + offset, strings[i]);
        offset += strlen(strings[i]);
    }

    return result;
}
int main(){
	printf("Entering Shell\n");
	int ps1_changed=0;
	char *ip=(char*)malloc(sizeof(char)*MAX_SIZE);
	// char ps1[MAX_SIZE];
	char *ps1=(char*)malloc(sizeof(char)*MAX_SIZE);
	int pid;
	char path[MAX_SIZE]="/usr/bin:/bin:/sbin";
	getcwd(ps1,MAX_SIZE);
	strcat(ps1,">");
	while(strcmp(ip,"exit")!=0){
		printf("\033[1;33m%s\033[0m",ps1); // outputting colored ps1 for more readability in yellow
		scanf("%[^\n]%*c",ip);
		if(strcmp(ip,"exit")==0){
			break;
		}
		char * buf=is_cmd_set_path(ip);
			
		if(buf!=NULL){
			// just set the path
			char * path_var=strtok(buf,"=");
			path_var=strtok(NULL,"=");
			// printf("%s\n",path_var);
			if(path_var==NULL){
				printf("could not set path to this...\n");
				return 1;
			}
			else{
				strcpy(path,path_var);
				printf("New Path: %s\n",path);
			}
		}
		else if (is_cd(ip)!=NULL)
		{
			char * path=is_cd(ip);
			if(chdir(path)!=0){
				perror("Error while changing directory: ");
			}
			if(!ps1_changed){
				getcwd(ps1,MAX_SIZE);
				strcat(ps1,">");
			}
		}
		else if(is_set_PS1(ip)!=NULL){
			char * new_ps1=is_set_PS1(ip);
			if(strcmp(new_ps1,"\"\\w$\"")==0 || strcmp(new_ps1,"\'\\w$\'")==0){
				ps1_changed=0;
				getcwd(ps1,MAX_SIZE);
				strcat(ps1,">");
			}
			else{
				ps1_changed=1;
				ps1=new_ps1;
			}
		}
		else{
			pid=fork();
			if(pid==0){
				char * output_file=is_io_redirect(ip,output);
				if(output_file!=NULL){
					output_file=remove_spaces(output_file);
					freopen(output_file,"w",stdout);
				}
				char * input_file=is_io_redirect(ip,input);
				if(input_file!=NULL){
					input_file=remove_spaces(input_file);
					freopen(input_file,"r",stdin);
				}
				//reconstruct the input if either one non null
				if(input_file!=NULL || output_file!=NULL){
					ip=get_effective_ip(ip);
				}

				char ** paths=get_paths(path); // i am tokenizing the path variable with respect to ':' to get the various paths we must search from for looking for executables.
				int flg=0;
				for(int i=0;paths[i]!=NULL;i++){
					strcat(paths[i],ip);
					// printf("%s\n",paths[i]);
					char * const * args=interpret_cmd(paths[i]); // getting args
					if(execv(args[0],args)==0){
						flg=1; // indicates at least ek file path me thik se chala
					};	
				}
				if(flg==0){
					printf("No such file or directory...\n");
					exit(1);
				}
			}
			else{
				wait(0);
			}
		}
	}
	return 0;
}
"""

# %%
data=list()
data.append(prog1)
data.append(prog2)
data.append(prog3)
data.append(prog4)
embeddings=embeddings_model.embed_documents(data)
cs_mat=calculate_similarity_matrix(embeddings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 data.append(prog1)
#       3 data.append(prog2)
# ----> 4 data.append(prog3)
#       5 data.append(prog4)
#       6 embeddings=embeddings_model.embed_documents(data)
#
# NameError: name 'prog3' is not defined

# %%
embeddings[0]
# Out:
# [-0.002132246969267726,
#  -0.0392572246491909,
#  -0.03869261592626572,
#  -0.03677331283688545,
#  0.03579070046544075,
#  -0.02534317597746849,
#  0.0043149543926119804,
#  -0.10774797201156616,
#  0.008018054068088531,
#  0.018829191103577614,
#  0.01718980073928833,
#  0.013113494962453842,
#  0.04980989918112755,
#  0.06367447227239609,
#  -0.0018317864742130041,
#  -0.015411995351314545,
#  0.021047335118055344,
#  0.003916703164577484,
#  -0.04150179773569107,
#  0.01855463907122612,
#  -0.031883012503385544,
#  0.022295599803328514,
#  -0.033604931086301804,
#  -0.0876757875084877,
#  -0.02468813769519329,
#  0.000336589349899441,
#  -0.0004722393932752311,
#  -0.06004716455936432,
#  -0.0014321620110422373,
#  -0.05862673744559288,
#  -0.05455465987324715,
#  -0.025202281773090363,
#  0.007887834683060646,
#  -0.061995912343263626,
#  1.5396649359900039e-06,
#  0.02620883658528328,
#  -0.012137589044868946,
#  0.036336954683065414,
#  -0.05551576241850853,
#  -0.01142644602805376,
#  0.047959815710783005,
#  0.051850300282239914,
#  -0.006311357486993074,
#  0.007307614665478468,
#  0.010267837904393673,
#  -0.01796710304915905,
#  0.005009262356907129,
#  -0.03140433132648468,
#  0.021699175238609314,
#  -0.022267237305641174,
#  -0.011849576607346535,
#  -0.10986494272947311,
#  0.07636567205190659,
#  -0.05675971508026123,
#  0.009220815263688564,
#  -0.02648383006453514,
#  0.0016885030781850219,
#  0.04888395592570305,
#  0.004301674198359251,
#  0.031934283673763275,
#  0.04189363867044449,
#  -0.059278685599565506,
#  0.02303369902074337,
#  0.04108940064907074,
#  0.06212589889764786,
#  0.009031174704432487,
#  0.04545396938920021,
#  -0.026196466758847237,
#  -0.017637962475419044,
#  0.039697855710983276,
#  0.01911173202097416,
#  -0.0364745669066906,
#  0.013109401799738407,
#  0.03388296067714691,
#  0.006055647507309914,
#  -0.1265716254711151,
#  0.029779711738228798,
#  -0.04056723788380623,
#  0.020561743527650833,
#  2.1863267818389431e-07,
#  -0.09778892248868942,
#  -0.012430695816874504,
#  0.015293211676180363,
#  -0.007738112937659025,
#  0.022473014891147614,
#  -0.006295458879321814,
#  0.05659511685371399,
#  0.040756955742836,
#  0.01336551271378994,
#  -0.01061240117996931,
#  -0.0339064821600914,
#  -0.002652422059327364,
#  -0.05347972363233566,
#  -0.01210007630288601,
#  0.024992631748318672,
#  0.016790252178907394,
#  0.011642022989690304,
#  0.07340117543935776,
#  0.03457493335008621,
#  0.025646202266216278,
#  -0.01706906221807003,
#  -0.016741551458835602,
#  0.016883058473467827,
#  0.040131792426109314,
#  -0.052878376096487045,
#  -0.04180017486214638,
#  -0.02591991052031517,
#  0.027213139459490776,
#  0.0012270340230315924,
#  -0.03521553799510002,
#  -0.02509239688515663,
#  0.057317622005939484,
#  -0.04218634217977524,
#  -0.007151286583393812,
#  0.009988165460526943,
#  -0.048268504440784454,
#  0.052210770547389984,
#  -0.001780930906534195,
#  -0.024043571203947067,
#  0.0322590246796608,
#  0.0791371539235115,
#  -0.007787380367517471,
#  -0.00046634540194645524,
#  -0.024695003405213356,
#  -0.04368501529097557,
#  0.04994373396039009,
#  0.04463309049606323,
#  0.02840457670390606,
#  0.0033047841861844063,
#  -0.032583512365818024,
#  0.006918774452060461,
#  -0.006167334038764238,
#  0.003190736984834075,
#  0.003002618905156851,
#  0.060986485332250595,
#  0.013504735194146633,
#  -0.035479940474033356,
#  0.026173697784543037,
#  -0.009881880134344101,
#  0.03718545287847519,
#  0.033684320747852325,
#  0.014432928524911404,
#  0.03186692297458649,
#  -0.02488434873521328,
#  0.030828213319182396,
#  0.03062920831143856,
#  0.05425475165247917,
#  9.517140907649322e-35,
#  0.013578193262219429,
#  -0.026405271142721176,
#  0.01763305626809597,
#  -0.03902100771665573,
#  -0.04411967471241951,
#  0.020157182589173317,
#  0.03156164661049843,
#  -0.003822164610028267,
#  -0.008590368553996086,
#  0.043908506631851196,
#  -0.01822756975889206]

# %%
import hashlib
from simhash import Simhash
def generate_hashes(content, m, n):
    """
    Generate hashes for every m-byte subsequence of the content.
    Keep the n smallest hashes.
    """
    hashes = []
    for i in range(0, len(content) - m + 1, m):
        subsequence = content[i:i+m]
        hash_value = hashlib.md5(subsequence.encode()).hexdigest()
        # hash_value=Simhash(subsequence).value
        hashes.append(hash_value)

    return sorted(hashes)[:n]

def jaccard_similarity(set1, set2):
    """
    Calculate the Jaccard similarity between two sets.
    """
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    return intersection / union if union != 0 else 0  # Handle division by zero

def simhash_simi(prog1,prog2, m, n):
    # Programs
    
    # Generate hashes for each program
    #m = Number of bytes per subsequence
    #n =  Number of smallest hashes to retain
    hashes1 = generate_hashes(prog1, m, n)
    hashes2 = generate_hashes(prog2, m, n)

    # Calculate Jaccard similarity of the sets of retained hashes
    similarity = jaccard_similarity(set(hashes1), set(hashes2))
    return similarity

# %%
data = list()
import os
directory_path = "../testcases/testfiles"
text_files = [file for file in os.listdir(directory_path)]
for txt_file in text_files:
    print(txt_file)
    file_path = os.path.join(directory_path, txt_file)
    with open(file_path, "r", encoding="utf-8") as f:
        txt = f.read()
        data.append(txt)
# Out:
# 112103015.patch
# 112103079-1.patch
# inodenumber-A.c
# inodenumbersim.c
# inodenumber.c
# graph1.c
# graph2.c

# %%
data[1]
# Out:
# 'diff --git a/defs.h b/defs.h\nindex 82fb982..33b84a4 100644\n--- a/defs.h\n+++ b/defs.h\n@@ -120,6 +120,7 @@ void            userinit(void);\n int             wait(void);\n void            wakeup(void*);\n void            yield(void);\n+int\t\t nice(int,int);\n \n // swtch.S\n void            swtch(struct context**, struct context*);\ndiff --git a/lapic.c b/lapic.c\nindex b22bbd7..c83e21e 100644\n--- a/lapic.c\n+++ b/lapic.c\n@@ -51,6 +51,13 @@ lapicw(int index, int value)\n   lapic[ID];  // wait for write to finish, by reading\n }\n \n+void\n+change_time_quantum(int priority)\n+{\n+\tlapicw(TICR,5000000*priority);\n+}\n+\n+\n void\n lapicinit(void)\n {\ndiff --git a/proc.c b/proc.c\nindex 806b1b1..aa9bc4d 100644\n--- a/proc.c\n+++ b/proc.c\n@@ -17,7 +17,7 @@ static struct proc *initproc;\n int nextpid = 1;\n extern void forkret(void);\n extern void trapret(void);\n-\n+extern void change_time_quantum(int);\n static void wakeup1(void *chan);\n \n void\n@@ -88,6 +88,7 @@ allocproc(void)\n found:\n   p->state = EMBRYO;\n   p->pid = nextpid++;\n+  p->priority = 1;\n \n   release(&ptable.lock);\n \n@@ -198,6 +199,7 @@ fork(void)\n   }\n   np->sz = curproc->sz;\n   np->parent = curproc;\n+  np->priority = np->parent->priority + 1;\n   *np->tf = *curproc->tf;\n \n   // Clear %eax so that fork returns 0 in the child.\n@@ -319,23 +321,39 @@ wait(void)\n //  - swtch to start running that process\n //  - eventually that process transfers control\n //      via swtch back to the scheduler.\n+\n+\n void\n scheduler(void)\n {\n   struct proc *p;\n+  struct proc* temp;\n   struct cpu *c = mycpu();\n   c->proc = 0;\n   \n   for(;;){\n     // Enable interrupts on this processor.\n     sti();\n-\n+    struct proc* selected;\n     // Loop over process table looking for process to run.\n     acquire(&ptable.lock);\n     for(p = ptable.proc; p < &ptable.proc[NPROC]; p++){\n       if(p->state != RUNNABLE)\n         continue;\n-\n+      p->priority++;\n+      selected = p;\n+      \n+      for(temp = ptable.proc;temp < &ptable.proc[NPROC];temp++){\n+      \t if(temp->state != RUNNABLE){\n+      \t   continue;\n+      \t }\n+      \t if(selected->priority < temp->priority){\n+      \t   selected = temp;\n+      \t }\n+      }\n+      \n+      p = selected;\n+      change_time_quantum(p->priority);\n       // Switch to chosen process.  It is the process\'s job\n       // to release ptable.lock and then reacquire it\n       // before jumping back to us.\n@@ -532,3 +550,16 @@ procdump(void)\n     cprintf("\\n");\n   }\n }\n+\n+int\n+nice(int pid, int priority)\n+{\n+\tstruct proc* p;\n+\tfor(p = ptable.proc;p<&ptable.proc[NPROC];p++){\n+\t\tif(p->pid == pid){\n+\t\t\tp->priority = priority;\n+\t\t\tbreak;\n+\t\t}\n+\t}\n+\treturn pid;\n+}\ndiff --git a/proc.h b/proc.h\nindex 1647114..3f9dcd0 100644\n--- a/proc.h\n+++ b/proc.h\n@@ -37,6 +37,7 @@ enum procstate { UNUSED, EMBRYO, SLEEPING, RUNNABLE, RUNNING, ZOMBIE };\n // Per-process state\n struct proc {\n   uint sz;                     // Size of process memory (bytes)\n+  int priority;\n   pde_t* pgdir;                // Page table\n   char *kstack;                // Bottom of kernel stack for this process\n   enum procstate state;        // Process state\ndiff --git a/syscall.c b/syscall.c\nindex ee85261..ebc1780 100644\n--- a/syscall.c\n+++ b/syscall.c\n@@ -103,6 +103,7 @@ extern int sys_unlink(void);\n extern int sys_wait(void);\n extern int sys_write(void);\n extern int sys_uptime(void);\n+extern int sys_nice(void);\n \n static int (*syscalls[])(void) = {\n [SYS_fork]    sys_fork,\n@@ -126,6 +127,7 @@ static int (*syscalls[])(void) = {\n [SYS_link]    sys_link,\n [SYS_mkdir]   sys_mkdir,\n [SYS_close]   sys_close,\n+[SYS_nice]    sys_nice,\n };\n \n void\ndiff --git a/syscall.h b/syscall.h\nindex bc5f356..fc06372 100644\n--- a/syscall.h\n+++ b/syscall.h\n@@ -20,3 +20,4 @@\n #define SYS_link   19\n #define SYS_mkdir  20\n #define SYS_close  21\n+#define SYS_nice   22\ndiff --git a/sysproc.c b/syspro ...

# %%
simhash_simi(data[2],data[4])
# Out:
# ['0121b5fadb6ecf10661c4746a7146927', '018d00ee59b556bb80e7cde3a50f5c75', '018d5209e9f4af2a63f67460f9e19d8b', '018d5209e9f4af2a63f67460f9e19d8b', '02b1d807ee1d30e632767f4a59a05226', '02b1d807ee1d30e632767f4a59a05226', '031d37a5cda8e178d1e06c1f47f5de4c', '0362a1f342722934184c0ca47ccee2ca', '03777ae88b1d3d68ea735792007c507b', '03b078541fd0b33c1a23738ff1422b99', '043b03017a03d85d0cf165bc80d58673', '04488539d43886a10a94434261330eee', '044e176613b7c32d6f74cd0acdc49bc7', '0477d94a457c3e72610fd6cb5ab09130', '04ff8b9d115646594466d6dc221d830e', '054b9e7c146a4d2435fb61595db2ac40', '05d43981e7cc8e8349d260918894a596', '0621ca2eb0ca75ab0b0ea3996f7d9432', '0621ca2eb0ca75ab0b0ea3996f7d9432', '0621ca2eb0ca75ab0b0ea3996f7d9432', '0621ca2eb0ca75ab0b0ea3996f7d9432', '0621ca2eb0ca75ab0b0ea3996f7d9432', '0621ca2eb0ca75ab0b0ea3996f7d9432', '0621ca2eb0ca75ab0b0ea3996f7d9432', '0621ca2eb0ca75ab0b0ea3996f7d9432', '065c63c3feccf76685f52ab22ef20df9', '0662cb67d7c3985e20132143e6baa785', '0662cb67d7c3985e20132143e6baa785', '0662cb67d7c3985e20132143e6baa785', '0689d724c83c13efe725e011c303d643', '0689d724c83c13efe725e011c303d643', '07915255d64730d06d2349d11ac3bfd8', '07915255d64730d06d2349d11ac3bfd8', '07cc694b9b3fc636710fa08b6922c42b', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09bde4b09c3a5c58f92e673f474a30f2', '09bde4b09c3a5c58f92e673f474a30f2', '0a7f2007e321b0faffb66cb358d283bd', '0a7f2007e321b0faffb66cb358d283bd', '0b27918290ff5323bea1e3b78a9cf04e', '0b7129b9bd6c9f5c3081a6aa5d292c44', '0c0d6288a4e6c1ec3e1f722438f08a31', '0c0d6288a4e6c1ec3e1f722438f08a31', '0c0d6288a4e6c1ec3e1f722438f08a31', '0ce4778573a5b30155e27a952e2096f8', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0c ...
# 0.21287128712871287

# %%
simhash_simi(data[2],data[3])
# Out:
# ['0121b5fadb6ecf10661c4746a7146927', '018d00ee59b556bb80e7cde3a50f5c75', '018d5209e9f4af2a63f67460f9e19d8b', '018d5209e9f4af2a63f67460f9e19d8b', '02b1d807ee1d30e632767f4a59a05226', '02b1d807ee1d30e632767f4a59a05226', '031d37a5cda8e178d1e06c1f47f5de4c', '0362a1f342722934184c0ca47ccee2ca', '03777ae88b1d3d68ea735792007c507b', '03b078541fd0b33c1a23738ff1422b99', '043b03017a03d85d0cf165bc80d58673', '04488539d43886a10a94434261330eee', '044e176613b7c32d6f74cd0acdc49bc7', '0477d94a457c3e72610fd6cb5ab09130', '04ff8b9d115646594466d6dc221d830e', '054b9e7c146a4d2435fb61595db2ac40', '05d43981e7cc8e8349d260918894a596', '0621ca2eb0ca75ab0b0ea3996f7d9432', '0621ca2eb0ca75ab0b0ea3996f7d9432', '0621ca2eb0ca75ab0b0ea3996f7d9432', '0621ca2eb0ca75ab0b0ea3996f7d9432', '0621ca2eb0ca75ab0b0ea3996f7d9432', '0621ca2eb0ca75ab0b0ea3996f7d9432', '0621ca2eb0ca75ab0b0ea3996f7d9432', '0621ca2eb0ca75ab0b0ea3996f7d9432', '065c63c3feccf76685f52ab22ef20df9', '0662cb67d7c3985e20132143e6baa785', '0662cb67d7c3985e20132143e6baa785', '0662cb67d7c3985e20132143e6baa785', '0689d724c83c13efe725e011c303d643', '0689d724c83c13efe725e011c303d643', '07915255d64730d06d2349d11ac3bfd8', '07915255d64730d06d2349d11ac3bfd8', '07cc694b9b3fc636710fa08b6922c42b', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09b86532e87eaa8fc67f4a27d1f8750c', '09bde4b09c3a5c58f92e673f474a30f2', '09bde4b09c3a5c58f92e673f474a30f2', '0a7f2007e321b0faffb66cb358d283bd', '0a7f2007e321b0faffb66cb358d283bd', '0b27918290ff5323bea1e3b78a9cf04e', '0b7129b9bd6c9f5c3081a6aa5d292c44', '0c0d6288a4e6c1ec3e1f722438f08a31', '0c0d6288a4e6c1ec3e1f722438f08a31', '0c0d6288a4e6c1ec3e1f722438f08a31', '0ce4778573a5b30155e27a952e2096f8', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0c ...
# 0.4900662251655629

# %%
from difflib import SequenceMatcher 
similarity = SequenceMatcher(None, data[2], data[3]).ratio()
print("Similarity - ", similarity)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[103], line 2
#       1 from difflib import SequenceMatcher
# ----> 2 similarity = SequenceMatcher(None, data[2], data[3]).ratio()
#       3 print("Similarity - ", similarity)
#
# IndexError: list index out of range

# %%
prog1 = """
import heapq

class Graph:
    def __init__(self, num_vertices):
        self.num_vertices = num_vertices
        self.adj_list = [[] for _ in range(num_vertices)]

    def add_edge(self, u, v, weight):
        self.adj_list[u].append((v, weight))
        self.adj_list[v].append((u, weight))  # Assuming undirected graph

def dijkstra(graph, source):
    distances = [float('inf')] * graph.num_vertices
    distances[source] = 0

    pq = [(0, source)]  # Priority queue to store (distance, vertex) pairs
    while pq:
        dist_u, u = heapq.heappop(pq)
        if dist_u > distances[u]:  # Skip if we have found a better distance already
            continue
        for v, weight in graph.adj_list[u]:
            if distances[u] + weight < distances[v]:
                distances[v] = distances[u] + weight
                heapq.heappush(pq, (distances[v], v))

    return distances

# Example usage:
# Create a graph
num_vertices = 5
graph = Graph(num_vertices)
graph.add_edge(0, 1, 10)
graph.add_edge(0, 2, 5)
graph.add_edge(1, 2, 2)
graph.add_edge(1, 3, 1)
graph.add_edge(2, 3, 9)
graph.add_edge(2, 4, 2)
graph.add_edge(3, 4, 4)

# Compute shortest distances from source vertex (e.g., vertex 0)
source_vertex = 0
shortest_distances = dijkstra(graph, source_vertex)
print("Shortest distances from vertex", source_vertex)
for i, distance in enumerate(shortest_distances):
    print("Vertex", i, ":", distance)
"""
prog2 = """
class Graph:
    def __init__(self, num_vertices):
        self.num_vertices = num_vertices
        self.edges = []

    def add_edge(self, u, v, weight):
        self.edges.append((u, v, weight))

def kruskal(graph):
    # Function to find the parent of a vertex in a set
    def find(parent, vertex):
        if parent[vertex] == -1:
            return vertex
        return find(parent, parent[vertex])

    # Function to perform union of two sets
    def union(parent, rank, x, y):
        xroot = find(parent, x)
        yroot = find(parent, y)
        if rank[xroot] < rank[yroot]:
            parent[xroot] = yroot
        elif rank[xroot] > rank[yroot]:
            parent[yroot] = xroot
        else:
            parent[yroot] = xroot
            rank[xroot] += 1

    # Sort all the edges in increasing order of their weight
    graph.edges = sorted(graph.edges, key=lambda x: x[2])

    result = []  # List to store the resulting MST
    parent = [-1] * graph.num_vertices  # Parent array for union-find operations
    rank = [0] * graph.num_vertices  # Rank array for union-find operations

    for u, v, weight in graph.edges:
        x = find(parent, u)
        y = find(parent, v)
        if x != y:
            result.append((u, v, weight))
            union(parent, rank, x, y)

    return result

# Example usage:
# Create a graph
num_vertices = 6
graph = Graph(num_vertices)
graph.add_edge(0, 1, 4)
graph.add_edge(0, 2, 4)
graph.add_edge(1, 2, 2)
graph.add_edge(1, 0, 4)
graph.add_edge(2, 0, 4)
graph.add_edge(2, 1, 2)
graph.add_edge(2, 3, 3)
graph.add_edge(2, 5, 2)
graph.add_edge(2, 4, 4)
graph.add_edge(3, 2, 3)
graph.add_edge(3, 5, 3)
graph.add_edge(4, 2, 4)
graph.add_edge(4, 5, 3)
graph.add_edge(5, 2, 2)
graph.add_edge(5, 3, 3)
graph.add_edge(5, 4, 3)

# Compute the minimum spanning tree (MST) using Kruskal's algorithm
mst = kruskal(graph)
print("Minimum Spanning Tree (MST):")
for edge in mst:
    print(f"Edge: {edge[0]} - {edge[1]}, Weight: {edge[2]}")
"""
simhash_simi(prog1, prog2)
# Out:
# ['00082c0853d9608af2b2e3011e943da3', '00082c0853d9608af2b2e3011e943da3', '00d0149ae9d019b02194105b9957010e', '017163727bc806385f1453c130b4fce3', '032c40132e9c3cde3eec71c1e10f5299', '03d597a11bd973a2c97f5ba76aa32d67', '03d67473d30e68f2a5625dccb50dff4b', '03e5d90208eeb5c1b06c20ef1fb26539', '047b26d66309e1c428624cf57163f92e', '047b26d66309e1c428624cf57163f92e', '098f6bcd4621d373cade4e832627b4f6', '098f6bcd4621d373cade4e832627b4f6', '0a64135ce67a173bcb06c659629699fc', '0c3477e767e3ead787cbe38da3eb5826', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '0cf31b2c283ce3431794586df7b0996d', '
# 0.08527131782945736

# %%
prog3 = """class Graph:
    def __init__(self, num_vertices):
        self.num_vertices = num_vertices
        self.edges = []

    def add_edge(self, start, end, weight):
        self.edges.append((start, end, weight))

def kruskal_algorithm(graph):
    # Function to find the representative of a set
    def find_set(representatives, vertex):
        if representatives[vertex] == -1:
            return vertex
        return find_set(representatives, representatives[vertex])

    # Function to merge two sets
    def union_sets(representatives, ranks, vertex1, vertex2):
        root1 = find_set(representatives, vertex1)
        root2 = find_set(representatives, vertex2)
        if ranks[root1] < ranks[root2]:
            representatives[root1] = root2
        elif ranks[root1] > ranks[root2]:
            representatives[root2] = root1
        else:
            representatives[root2] = root1
            ranks[root1] += 1

    # Sort all the edges in increasing order of their weight
    graph.edges.sort(key=lambda x: x[2])

    minimum_spanning_tree = []  # List to store the resulting MST
    representatives = [-1] * graph.num_vertices  # Parent array for union-find operations
    ranks = [0] * graph.num_vertices  # Rank array for union-find operations

    for start, end, weight in graph.edges:
        root_start = find_set(representatives, start)
        root_end = find_set(representatives, end)
        if root_start != root_end:
            minimum_spanning_tree.append((start, end, weight))
            union_sets(representatives, ranks, root_start, root_end)

    return minimum_spanning_tree

# Example usage:
# Create a graph
num_vertices = 6
graph = Graph(num_vertices)
graph.add_edge(0, 1, 4)
graph.add_edge(0, 2, 4)
graph.add_edge(1, 2, 2)
graph.add_edge(1, 0, 4)
graph.add_edge(2, 0, 4)
graph.add_edge(2, 1, 2)
graph.add_edge(2, 3, 3)
graph.add_edge(2, 5, 2)
graph.add_edge(2, 4, 4)
graph.add_edge(3, 2, 3)
graph.add_edge(3, 5, 3)
graph.add_edge(4, 2, 4)
graph.add_edge(4, 5, 3)
graph.add_edge(5, 2, 2)
graph.add_edge(5, 3, 3)
graph.add_edge(5, 4, 3)

# Compute the minimum spanning tree (MST) using Kruskal's algorithm
mst = kruskal_algorithm(graph)
print("Minimum Spanning Tree (MST):")
for edge in mst:
    print(f"Edge: {edge[0]} - {edge[1]}, Weight: {edge[2]}")
"""

# %%
simhash_simi(prog2, prog3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 simhash_simi(prog2, prog3)
#
# TypeError: simhash_simi() missing 2 required positional arguments: 'm' and 'n'

# %%
#reading the dataset
ground_truth = open("/home/bhushan/Downloads/ground-truth-anon.txt", "r")

# %%
# Define an empty dictionary to store the directory paths and names
directory_dict = {}

# Open the text file and read line by line
with open("/home/bhushan/Downloads/ground-truth-anon.txt", "r") as file:
    directory_path = None
    names_list = []

    # Iterate over each line in the file
    for line in file:
        line = line.strip()  # Remove leading and trailing whitespace
        if line.startswith("- "):  # Check if line starts with "-"
            if directory_path is not None:  # Check if there is an existing directory path
                directory_dict[directory_path] = names_list  # Add the directory path and names list to the dictionary
                names_list = []  # Reset the names list for the new directory path
            directory_path = line[2:]  # Extract the directory path from the line
        else:
            # Split the line by comma and add the names to the names list
            names = line.split(",")
            names_list.append(names)

    # Add the last directory path and names list to the dictionary
    if directory_path is not None:
        directory_dict[directory_path] = names_list

# %%
directory_dict
# Out:
# {'A2016/Z1/Z1': [['student2956'],
#   ['student7386', 'student5378', 'student9538'],
#   ['student6018'],
#   ['student2821', 'student8295'],
#   ['student4934', 'student6617'],
#   ['student8598', 'student3331', 'student5573', 'student9498', 'student8796'],
#   ['student7888', 'student7704'],
#   ['student4959', 'student1482', 'student1915'],
#   ['student1200'],
#   ['student2939', 'student9949'],
#   ['student5512', 'student4852'],
#   ['student3288'],
#   ['student2463'],
#   ['student3116'],
#   ['student8631'],
#   ['student3424'],
#   ['student1828'],
#   ['student7495', 'student5741'],
#   ['student8520'],
#   ['student9160', 'student7443'],
#   ['student8357', 'student6877', 'student6776', 'student9805'],
#   ['student2086', 'student7173'],
#   ['student5789', 'student5673'],
#   ['student9358', 'student2953']],
#  'A2016/Z1/Z2': [['student2956'],
#   ['student7386', 'student5378', 'student4124', 'student9538'],
#   ['student6018'],
#   ['student8598', 'student3331', 'student5573', 'student9498', 'student8796'],
#   ['student7888', 'student7704', 'student6534', 'student5381'],
#   ['student4959', 'student1482', 'student1915'],
#   ['student1200'],
#   ['student2939', 'student9949'],
#   ['student8124'],
#   ['student2821', 'student4155'],
#   ['student5512', 'student4852', 'student2155'],
#   ['student1326', 'student1624'],
#   ['student3288'],
#   ['student2463'],
#   ['student3116'],
#   ['student8631'],
#   ['student8187', 'student3631'],
#   ['student8863'],
#   ['student3424'],
#   ['student1828'],
#   ['student6054', 'student7341'],
#   ['student4934'],
#   ['student8520'],
#   ['student9160', 'student7443'],
#   ['student1120', 'student5226', 'student5741'],
#   ['student1266']],
#  'A2016/Z1/Z3': [['student7386', 'student5378', 'student9538'],
#   ['student6018'],
#   ['student2821', 'student8295', 'student4155', 'student2197'],
#   ['student8598',
#    'student3331',
#    'student5573',
#    'student9498',
#    'student4420',
#    'student6617',
#    'student8796'],
#   ['student4059',
#    'student7704',
#    'student6534',
#    'student4934',
#    'student2925',
#    'student4280'],
#   ['student4959', 'student1482', 'student1915'],
#   ['student1200'],
#   ['student2939', 'student9949'],
#   ['student8124'],
#   ['student5789'],
#   ['student5512', 'student4852'],
#   ['student1326', 'student3560'],
#   ['student5381'],
#   ['student3288'],
#   ['student2463'],
#   ['student3116'],
#   ['student8631'],
#   ['student4863', 'student5380'],
#   ['student9821', 'student8133'],
#   ['student3424', 'student3756'],
#   ['student1828'],
#   ['student7495', 'student5741'],
#   ['student1466', 'student1266'],
#   ['student6054', 'student7341'],
#   ['student9805', 'student8357', 'student6776'],
#   ['student5581', 'student8089'],
#   ['student3350', 'student4226', 'student4575'],
#   ['student2831', 'student4343'],
#   ['student8520'],
#   ['student3567', 'student1453'],
#   ['student5170', 'student8540']],
#  'A2016/Z1/Z4': [['student2956'],
#   ['student6018'],
#   ['student2821', 'student8295', 'student4155'],
#   ['student8598', 'student3331', 'student9498'],
#   ['student7888',
#    'student7704',
#    'student6534',
#    'student6617',
#    'student2925',
#    'student5381'],
#   ['student4959', 'student1482', 'student1915'],
#   ['student1200'],
#   ['student2939', 'student9949', 'student5649'],
#   ['student4124', 'student9538'],
#   ['student8124'],
#   ['student5512', 'student4852'],
#   ['student1266', 'student9931'],
#   ['student3288'],
#   ['student2463'],
#   ['student3116'],
#   ['student8631'],
#   ['student3424', 'student1845'],
#   ['student1828'],
#   ['student8796'],
#   ['student7495', 'student5741'],
#   ['student6054', 'student7341'],
#   ['student6776', 'student1483', 'student8357', 'student4934'],
#   ['student7123', 'student2142'],
#   ['student8520'],
#   ['student1616'],
#   ['student3671', 'student7802'],
#   ['student9160', 'student7443'],
#   ['student1188', 'student8199'],
#   ['student2887', 'student9805'],
#   ['student2806', 'student4108'],
#   ['student5899', 'student7255'],
#   ['student3856', 'student4100']],
#  'A2016/Z2/Z1': [['student7386', 'student5380', 'student6054'],
#   ['student8192', 'student2736'],
#   ['student4161'],
#   ['student3165'],
#   ['student4124'],
#   ['student8124'],
#   ['student2221'],
#   ['student8035'],
#   ['student2634'],
#   ['student8069'],
#   ['student1616', 'student8886'],
#   ['student3301'],
#   ['student3421', 'student9296'],
#   ['student6995'],
#   ['student3517'],
#   ['student8796'],
#   ['student7090'],
#   ['student5612', 'student5581'],
#   ['student7956', 'student7697'],
#   ['student3736'],
#   ['student2925', 'student2821', 'student9949', 'student2939', 'student9113'],
#   ['student2547'],
#   ['student1269'],
#   ['student1220'],
#   ['student8753'],
#   ['student3288'],
#   ['student3717', 'student2508', 'student1313'],
#   ['student3425', 'student1639'],
#   ['student9160', 'student2526'],
#   ['student1120', 'student5624', 'student3567'],
#   ['student7255'],
#   ['student3350'],
#   ['student7888', 'student6617', 'student8598', 'student5573'],
#   ['student6776'],
#   ['student9931', 'student5961'],
#   ['student8317'],
#   ['student5512'],
#   ['student8864'],
#   ['student9451'],
#   ['student8794'],
#   ['student5957'],
#   ['student4770'],
#   ['student6534'],
#   ['student9498'],
#   ['student4280'],
#   ['student3331'],
#   ['student7704'],
#   ['student8089'],
#   ['student2421'],
#   ['student2437', 'student5636'],
#   ['student8199', 'student4100'],
#   ['student6001'],
#   ['student3671'],
#   ['student8195'],
#   ['student3732'],
#   ['student2953'],
#   ['student4059'],
#   ['student7293'],
#   ['student3572'],
#   ['student9864'],
#   ['student4644'],
#   ['student2197'],
#   ['student6122'],
#   ['student1200'],
#   ['student2406'],
#   ['student5355'],
#   ['student1482'],
#   ['student8892']],
#  'A2016/Z2/Z2': [['student7386', 'student6999'],
#   ['student8192', 'student2736'],
#   ['student4161'],
#   ['student3165'],
#   ['student4124'],
#   ['student2221'],
#   ['student9538',
#    'student3631',
#    'student5581',
#    'student5612',
#    'student2406',
#    'student8067'],
#   ['student8035'],
#   ['student2634'],
#   ['student1845'],
#   ['student1616', 'student8886'],
#   ['student3421', 'student9296'],
#   ['student6995'],
#   ['student3517'],
#   ['student8796', 'student8598', 'student5573'],
#   ['student7090'],
#   ['student7956', 'student4043'],
#   ['student3736'],
#   ['student2908'],
#   ['student4665'],
#   ['student2925'],
#   ['student1269'],
#   ['student3717', 'student2508', 'student1313'],
#   ['student3425', 'student1639', 'student8561'],
#   ['student3315', 'student1453'],
#   ['student1120', 'student5624', 'student3567'],
#   ['student3350'],
#   ['student9949'],
#   ['student2513', 'student6364'],
#   ['student7255'],
#   ['student7888', 'student5660'],
#   ['student6776'],
#   ['student9931', 'student5961'],
#   ['student2160', 'student6960'],
#   ['student5512'],
#   ['student8864'],
#   ['student9451'],
#   ['student6594', 'student4682'],
#   ['student4770'],
#   ['student4934', 'student3386', 'student4824'],
#   ['student9498'],
#   ['student1772', 'student5268'],
#   ['student4280'],
#   ['student8089'],
#   ['student2421'],
#   ['student2437'],
#   ['student1237', 'student4100'],
#   ['student3671'],
#   ['student8195'],
#   ['student3732'],
#   ['student7085'],
#   ['student2953', 'student1649'],
#   ['student4059'],
#   ['student7293'],
#   ['student3572'],
#   ['student1738', 'student9569'],
#   ['student4185', 'student2585'],
#   ['student9864'],
#   ['student4644'],
#   ['student2197'],
#   ['student6122'],
#   ['student5298', 'student1200'],
#   ['student5355'],
#   ['student5380'],
#   ['student4322', 'student6010'],
#   ['student1482'],
#   ['student3136', 'student6705'],
#   ['student2157', 'student6516'],
#   ['student5611', 'student2967'],
#   ['student8892'],
#   ['student3301']],
#  'A2016/Z2/Z3': [['student7386', 'student7888'],
#   ['student8192', 'student8957'],
#   ['student4161'],
#   ['student3165'],
#   ['student4124'],
#   ['student8124'],
#   ['student2221'],
#   ['student9538'],
#   ['student8035'],
#   ['student2634'],
#   ['student4290'],
#   ['student1845', 'student3594'],
#   ['student3560', 'student9473'],
#   ['student8069',
#    'student2526',
#    'student3421',
#    'student9160',
#    'student7255',
#    'student8089',
#    'student4420',
#    'student8043'],
#   ['student1616', 'student8886'],
#   ['student6303'],
#   ['student6743', 'student5789'],
#   ['student6995'],
#   ['student1477', 'student4082'],
#   ['student8796', 'student5573', 'student8598'],
#   ['student7090'],
#   ['student5612', 'student5581', 'student4949', 'student1482'],
#   ['student7956'],
#   ['student3736'],
#   ['student2925'],
#   ['student1269'],
#   ['student8753', 'student8520'],
#   ['student3425', 'student1639', 'student1266'],
#   ['student6054', 'student5380'],
#   ['student3315', 'student1453', 'student3567'],
#   ['student1120', 'student5624', 'student8631'],
#   ['student3350'],
#   ['student9949'],
#   ['student2513', 'student6364'],
#   ['student8295'],
#   ['student6776'],
#   ['student9931', 'student5961'],
#   ['student8317'],
#   ['student2160'],
#   ['student8199', 'student4100'],
#   ['student5512', 'student8864'],
#   ['student9451'],
#   ['student6594', 'student4682', 'student3572'],
#   ['student5957'],
#   ['student4770', 'student5899'],
#   ['student6534'],
#   ['student9498', 'student7911'],
#   ['student7704'],
#   ['student8561'],
#   ['student6001'],
#   ['student8195'],
#   ['student3732'],
#   ['student7485'],
#   ['student4036'],
#   ['student7085'],
#   ['student2953', 'student1649'],
#   ['student4824'],
#   ['student7293'],
#   ['student1738', 'student9569'],
#   ['student2197'],
#   ['student6122'],
#   ['student7980'],
#   ['student5298', 'student1200'],
#   ['student5355'],
#   ['student2508', 'student1313'],
#   ['student4322', 'student7616'],
#   ['student6877'],
#   ['student4108', 'student7173'],
#   ['student4554', 'student8560'],
#   ['student4575'],
#   ['student3219'],
#   ['student5496'],
#   ['student5236'],
#   ['student4473', 'student6516'],
#   ['student7673'],
#   ['student3108'],
#   ['student8892'],
#   ['student3301']],
#  'A2016/Z2/Z4': [['student4161'],
#   ['student8124'],
#   ['student2221'],
#   ['student9538'],
#   ['student2956', 'student5284'],
#   ['student2634'],
#   ['student8069'],
#   ['student1616', 'student8886'],
#   ['student2351'],
#   ['student6053'],
#   ['student3421', 'student4059', 'student2526'],
#   ['student3756',
#    'student8598',
#    'student8796',
#    'student7888',
#    'student5573',
#    'student4420'],
#   ['student5612', 'student3631'],
#   ['student7956'],
#   ['student3736'],
#   ['student2908'],
#   ['student2925'],
#   ['student1269'],
#   ['student6054', 'student5380'],
#   ['student1120', 'student5624', 'student8631'],
#   ['student3350'],
#   ['student9949'],
#   ['student2513', 'student6364'],
#   ['student4155'],
#   ['student7255'],
#   ['student8317'],
#   ['student2160'],
#   ['student5512'],
#   ['student8864'],
#   ['student9451'],
#   ['student2508', 'student2340', 'student1313'],
#   ['student5957'],
#   ['student6534'],
#   ['student4934'],
#   ['student9498'],
#   ['student4280'],
#   ['student8089'],
#   ['student8199', 'student4100', 'student9805'],
#   ['student9476', 'student7180'],
#   ['student3671'],
#   ['student3732'],
#   ['student7085'],
#   ['student2953'],
#   ['student4824'],
#   ['student7293'],
#   ['student3572'],
#   ['student1738'],
#   ['student2197'],
#   ['student5298', 'student1200'],
#   ['student2406'],
#   ['student5355', 'student4644'],
#   ['student4322'],
#   ['student6743', 'student5263'],
#   ['student1029', 'student2585'],
#   ['student6877', 'student8357'],
#   ['student9569'],
#   ['student2447'],
#   ['student5659', 'student6516'],
#   ['student5829', 'student4415'],
#   ['student5611', 'student2967'],
#   ['student8892', 'student7678'],
#   ['student3301']],
#  'A2016/Z3/Z1': [['student2956'],
#   ['student8199', 'student4100'],
#   ['student3856', 'student4554'],
#   ['student6001'],
#   ['student3671'],
#   ['student1845'],
#   ['student8195'],
#   ['student9998'],
#   ['student3421', 'student3759'],
#   ['student8069'],
#   ['student2267'],
#   ['student5899', 'student2526'],
#   ['student6054', 'student7341'],
#   ['student6995'],
#   ['student9160', 'student3732', 'student4770', 'student7255'],
#   ['student1266', 'student5805', 'student6332', 'student8561', 'student3425'],
#   ['student5284'],
#   ['student9097', 'student4343', 'student7258', 'student8187'],
#   ['student2086', 'student3567'],
#   ['student4161'],
#   ['student9946'],
#   ['student5496'],
#   ['student1616', 'student8886'],
#   ['student8035'],
#   ['student4036'],
#   ['student3350'],
#   ['student9949', 'student2364'],
#   ['student5170', 'student8540'],
#   ['student3517'],
#   ['student7085'],
#   ['student2953'],
#   ['student9391'],
#   ['student5573', 'student8598', 'student1483'],
#   ['student8295'],
#   ['student4934'],
#   ['student5261'],
#   ['student9538'],
#   ['student3315'],
#   ['student2704'],
#   ['student1021'],
#   ['student5649'],
#   ['student9498'],
#   ['student4665'],
#   ['student4059'],
#   ['student5612'],
#   ['student7090'],
#   ['student3736'],
#   ['student6617'],
#   ['student5298', 'student4973'],
#   ['student8264'],
#   ['student1772'],
#   ['student4280'],
#   ['student6776'],
#   ['student7888', 'student4420'],
#   ['student4824'],
#   ['student7293'],
#   ['student6516'],
#   ['student6303'],
#   ['student9931'],
#   ['student4322'],
#   ['student8317'],
#   ['student8892'],
#   ['student2664', 'student6484'],
#   ['student8670'],
#   ['student1326'],
#   ['student8089', 'student8774'],
#   ['student4124'],
#   ['student7193'],
#   ['student2634'],
#   ['student1482'],
#   ['student9821'],
#   ['student2806'],
#   ['student1200'],
#   ['student2221'],
#   ['student2463'],
#   ['student2406'],
#   ['student4108'],
#   ['student2967'],
#   ['student6594'],
#   ['student5624', 'student8631'],
#   ['student4682'],
#   ['student9238'],
#   ['student4860', 'student9923'],
#   ['student5611'],
#   ['student3108'],
#   ['student5380'],
#   ['student2547']],
#  'A2016/Z3/Z2': [['student2956'],
#   ['student8797', 'student8199', 'student1188', 'student4100'],
#   ['student3856', 'student4554'],
#   ['student6001'],
#   ['student8152', 'student3108', 'student8665'],
#   ['student3671', 'student2585'],
#   ['student1845', 'student3594'],
#   ['student8195', 'student5129', 'student1375'],
#   ['student5536', 'student2267'],
#   ['student3421', 'student9160', 'student3732', 'student4770', 'student7255'],
#   ['student5899',
#    'student2526',
#    'student9946',
#    'student8357',
#    'student5612',
#    'student1738',
#    'student4420',
#    'student4108'],
#   ['student1266', 'student5805', 'student8561', 'student3425'],
#   ['student5284', 'student9188', 'student4860', 'student9923'],
#   ['student1120'],
#   ['student2086', 'student3567', 'student5496'],
#   ['student4161'],
#   ['student1624', 'student6010'],
#   ['student1616', 'student8886', 'student2806'],
#   ['student9097', 'student5236', 'student8864', 'student8187'],
#   ['student4036'],
#   ['student5170', 'student8540'],
#   ['student4150'],
#   ['student7085'],
#   ['student5573', 'student7888', 'student4934', 'student1483'],
#   ['student5261'],
#   ['student9538', 'student5378'],
#   ['student3315'],
#   ['student2704'],
#   ['student1021'],
#   ['student9498'],
#   ['student4665'],
#   ['student9805', 'student8363'],
#   ['student4059'],
#   ['student7496', 'student7090'],
#   ['student3736'],
#   ['student7956', 'student9296'],
#   ['student6029'],
#   ['student4280'],
#   ['student6776'],
#   ['student4661', 'student5533'],
#   ['student4824'],
#   ['student8100'],
#   ['student7293'],
#   ['student7911', 'student3756'],
#   ['student6303'],
#   ['student2157', 'student1547'],
#   ['student9931', 'student5961'],
#   ['student8670'],
#   ['student4124'],
#   ['student7193'],
#   ['student2634'],
#   ['student1639', 'student7457'],
#   ['student9821'],
#   ['student1200'],
#   ['student2221'],
#   ['student2463'],
#   ['student2406'],
#   ['student6594'],
#   ['student8631'],
#   ['student9238'],
#   ['student3320', 'student1502'],
#   ['student5380'],
#   ['student2547']],
#  'A2016/Z3/Z3': [['student2956'],
#   ['student5533'],
#   ['student8152', 'student6001', 'student3546', 'student4059'],
#   ['student3671', 'student2585'],
#   ['student1845'],
#   ['student4554', 'student5805', 'student6332', 'student3425', 'student1266'],
#   ['student9097', 'student8051', 'student8187', 'student5829'],
#   ['student8069'],
#   ['student6054'],
#   ['student5284', 'student9188', 'student3219'],
#   ['student4770'],
#   ['student4161'],
#   ['student2526',
#    'student9946',
#    'student2086',
#    'student3567',
#    'student4155',
#    'student5830',
#    'student5649',
#    'student7255',
#    'student5612',
#    'student4661',
#    'student7888',
#    'student4420'],
#   ['student5496'],
#   ['student1616', 'student8886'],
#   ['student4036'],
#   ['student3350'],
#   ['student9949', 'student4415'],
#   ['student3517', 'student8430'],
#   ['student7085'],
#   ['student2953', 'student9805', 'student8357', 'student6877'],
#   ['student9391'],
#   ['student4082', 'student7980'],
#   ['student5573', 'student8598'],
#   ['student8295'],
#   ['student4934'],
#   ['student9538'],
#   ['student3315'],
#   ['student2704'],
#   ['student1021'],
#   ['student9498'],
#   ['student4665'],
#   ['student7496', 'student7090'],
#   ['student8264'],
#   ['student7956', 'student9296'],
#   ['student4280'],
#   ['student6776'],
#   ['student4824'],
#   ['student6516'],
#   ['student6303'],
#   ['student9931', 'student5961', 'student1375'],
#   ['student8317'],
#   ['student8892'],
#   ['student8670'],
#   ['student1326'],
#   ['student8089'],
#   ['student5939', 'student6613'],
#   ['student2634'],
#   ['student1639', 'student4647'],
#   ['student9821'],
#   ['student2371', 'student8724'],
#   ['student1200'],
#   ['student2221'],
#   ['student2463'],
#   ['student4108'],
#   ['student2967'],
#   ['student6594'],
#   ['student8631'],
#   ['student5611'],
#   ['student5624', 'student9923'],
#   ['student5380'],
#   ['student2547']],
#  'A2016/Z4/Z1': [['student2210', 'student2908'],
#   ['student3776'],
#   ['student3315', 'student1453', 'student8357'],
#   ['student2704'],
#   ['student8480'],
#   ['student5284',
#    'student9188',
#    'student8886',
#    'student3116',
#    'student1616',
#    'student8631',
#    'student7180'],
#   ['student3756', 'student4495', 'student2676', 'student1188', 'student4420'],
#   ['student3594', 'student2463', 'student1021'],
#   ['student3872', 'student8797', 'student8774'],
#   ['student3517', 'student5660', 'student9391'],
#   ['student2447'],
#   ['student2240'],
#   ['student9538'],
#   ['student4059'],
#   ['student2749', 'student1547'],
#   ['student7090'],
#   ['student6303'],
#   ['student6255', 'student6706'],
#   ['student7193'],
#   ['student1639', 'student4415'],
#   ['student4973'],
#   ['student2221'],
#   ['student6877', 'student2553']],
#  'A2016/Z4/Z2': [['student3776'],
#   ['student2704'],
#   ['student8480'],
#   ['student5284',
#    'student9188',
#    'student3872',
#    'student5624',
#    'student8886',
#    'student3116',
#    'student8631',
#    'student7180'],
#   ['student3594', 'student2463', 'student2513'],
#   ['student6999', 'student5185', 'student8110'],
#   ['student1624'],
#   ['student3567'],
#   ['student7485'],
#   ['student1616'],
#   ['student5236'],
#   ['student5170', 'student8540'],
#   ['student4082'],
#   ['student2240'],
#   ['student9538'],
#   ['student4059'],
#   ['student2749', 'student1547'],
#   ['student7293'],
#   ['student6303'],
#   ['student9931', 'student9071', 'student4959'],
#   ['student5939', 'student5581'],
#   ['student7193'],
#   ['student1639', 'student4415'],
#   ['student3320', 'student8518'],
#   ['student4973'],
#   ['student7457', 'student4420'],
#   ['student2221'],
#   ['student6877', 'student2553']],
#  'A2016/Z4/Z3': [['student4575',
#    'student2553',
#    'student5170',
#    'student8540',
#    'student6877'],
#   ['student3776'],
#   ['student3315', 'student1453', 'student8357'],
#   ['student2704'],
#   ['student8480'],
#   ['student3756', 'student7457', 'student4420'],
#   ['student4495', 'student2676'],
#   ['student3567'],
#   ['student5624', 'student8631', 'student8886', 'student1616', 'student3116'],
#   ['student3517', 'student9391'],
#   ['student4082'],
#   ['student9538'],
#   ['student7985'],
#   ['student7193'],
#   ['student1639', 'student4415'],
#   ['student4973'],
#   ['student2221']],
#  'A2016/Z4/Z4': [['student3776'],
#   ['student2704'],
#   ['student8480'],
#   ['student5284', 'student9188'],
#   ['student3594', 'student2463', 'student1021'],
#   ['student3872', 'student8631', 'student1616', 'student8774', 'student3116'],
#   ['student3517', 'student5562', 'student9391'],
#   ['student2965', 'student1192'],
#   ['student2240'],
#   ['student9538'],
#   ['student4059'],
#   ['student7193'],
#   ['student1639', 'student4415'],
#   ['student4973'],
#   ['student2221']],
#  'A2016/Z5/Z1': [['student7485', 'student5468'],
#   ['student3671', 'student7258', 'student4150', 'student5860'],
#   ['student4471', 'student5915'],
#   ['student3776'],
#   ['student3386',
#    'student5378',
#    'student8480',
#    'student9538',
#    'student8357',
#    'student8776',
#    'student1833',
#    'student8520',
#    'student6956'],
#   ['student1624'],
#   ['student2965', 'student8599'],
#   ['student3567'],
#   ['student7888'],
#   ['student7457', 'student7540', 'student2652'],
#   ['student4973'],
#   ['student6369'],
#   ['student1029', 'student2585'],
#   ['student8288'],
#   ['student4412'],
#   ['student1981', 'student1317'],
#   ['student5939', 'student4415'],
#   ['student2553', 'student1202'],
#   ['student8118', 'student4416'],
#   ['student3717', 'student2508'],
#   ['student6547', 'student6548']],
#  'A2016/Z5/Z2': [['student3776',
#    'student3386',
#    'student3315',
#    'student5378',
#    'student8480',
#    'student9538',
#    'student6547',
#    'student9823',
#    'student6956',
#    'student8776',
#    'student7485'],
#   ['student4973', 'student4438'],
#   ['student2676', 'student2068'],
#   ['student8288']],
#  'A2016/Z5/Z3': [['student3776'],
#   ['student5378',
#    'student4082',
#    'student8480',
#    'student9538',
#    'student6956',
#    'student8776'],
#   ['student5284'],
#   ['student1624'],
#   ['student3567'],
#   ['student3386', 'student8357'],
#   ['student5860'],
#   ['student3631', 'student5581'],
#   ['student5939', 'student4415']],
#  'B2016/Z1/Z1': [['student3872'],
#   ['student5420', 'student5533'],
#   ['student6303', 'student3517'],
#   ['student4150'],
#   ['student2111'],
#   ['student3077'],
#   ['student4614', 'student9935'],
#   ['student5261', 'student8157'],
#   ['student7249'],
#   ['student8774'],
#   ['student6516', 'student7341'],
#   ['student7457'],
#   ['student9463', 'student2267']],
#  'B2016/Z1/Z2': [['student8428', 'student5170'],
#   ['student5897', 'student8518'],
#   ['student1269'],
#   ['student8957', 'student2068'],
#   ['student3424'],
#   ['student4163'],
#   ['student4575', 'student5957'],
#   ['student8118', 'student4416'],
#   ['student7810', 'student7085'],
#   ['student9099']],
#  'B2016/Z1/Z3': [['student4736', 'student7054'],
#   ['student7425'],
#   ['student6018'],
#   ['student2035'],
#   ['student1269'],
#   ['student8139'],
#   ['student4389', 'student2364'],
#   ['student6507'],
#   ['student8598'],
#   ['student7457'],
#   ['student5222']],
#  'B2016/Z1/Z4': [['student3253'],
#   ['student4415'],
#   ['student7346', 'student7673'],
#   ['student4082', 'student5542'],
#   ['student2574', 'student4389']],
#  'B2016/Z2/Z1': [['student5378', 'student9352'],
#   ['student6018', 'student4430'],
#   ['student6053', 'student4430']],
#  'B2016/Z2/Z2': [['student7425', 'student5378', 'student9538'],
#   ['student8599'],
#   ['student4495', 'student2676']],
#  'B2016/Z2/Z3': [['student6547', 'student4419'],
#   ['student5939', 'student7001']],
#  'B2016/Z2/Z4': [['student6631', 'student4377'],
#   ['student8118', 'student4416']],
#  'B2016/Z3/Z1': [['student9391', 'student1833'],
#   ['student4280', 'student6029'],
#   ['student7713', 'student5162']],
#  'B2016/Z3/Z2': [['student6787', 'student2953'],
#   ['student2634', 'student3350'],
#   ['student4414', 'student8317'],
#   ['student6790', 'student1237'],
#   ['student5268', 'student9897'],
#   ['student8152', 'student6956'],
#   ['student3872', 'student5496']],
#  'B2016/Z3/Z3': [['student2755']],
#  'B2016/Z3/Z4': [['student7507', 'student3350', 'student5263'],
#   ['student8560'],
#   ['student5403'],
#   ['student7540'],
#   ['student3872', 'student6184']],
#  'B2016/Z3/Z5': [['student1547', 'student4473'],
#   ['student3872', 'student6184']],
#  'B2016/Z3/Z6': [['student1547', 'student4473'],
#   ['student3872', 'student6184']],
#  'B2016/Z4/Z1': [['student8100', 'student5162'],
#   ['student6053', 'student2210']],
#  'B2016/Z4/Z2': [['student6303', 'student6956']],
#  'B2016/Z4/Z3': [['student6303', 'student6956']],
#  'B2016/Z4/Z4': [['student6303', 'student6956']],
#  'B2016/Z5/Z1': [['student6353', 'student3410'],
#   ['student8724', 'student2371'],
#   ['student7085', 'student7180']],
#  'B2016/Z5/Z2': [],
#  'B2016/Z5/Z3': [],
#  'B2016/Z5/Z4': [],
#  'B2016/Z5/Z5': [],
#  'B2016/Z6/Z1': [['student7346', 'student4057']],
#  'B2016/Z6/Z2': [['student4057', 'student7346']],
#  'B2016/Z6/Z3': [['student4057', 'student7346']],
#  'B2016/Z6/Z4': [],
#  'A2017/Z1/Z1': [['student5005'],
#   ['student7709', 'student6471'],
#   ['student9547', 'student4749', 'student5861', 'student6795'],
#   ['student5374',
#    'student9705',
#    'student5383',
#    'student8142',
#    'student3871',
#    'student5193'],
#   ['student3624'],
#   ['student8566'],
#   ['student8954'],
#   ['student7043', 'student5816', 'student3836'],
#   ['student6582', 'student8522'],
#   ['student5068', 'student2468', 'student4152', 'student3506', 'student6681'],
#   ['student7632'],
#   ['student1080'],
#   ['student1037', 'student9884'],
#   ['student8172', 'student4096'],
#   ['student9486', 'student5494'],
#   ['student3424', 'student7090'],
#   ['student3732', 'student9569'],
#   ['student1710', 'student1412'],
#   ['student9993', 'student2045', 'student3367', 'student8298'],
#   ['student9221', 'student3866'],
#   ['student5622', 'student7514'],
#   ['student6168', 'student1366'],
#   ['student4100', 'student4554'],
#   ['student8157', 'student7495'],
#   ['student8997', 'student7178'],
#   ['student1600']],
#  'A2017/Z1/Z2': [['student5005'],
#   ['student7709', 'student6471'],
#   ['student5677',
#    'student7043',
#    'student8011',
#    'student8997',
#    'student5816',
#    'student3836',
#    'student7178',
#    'student9570'],
#   ['student5383', 'student8142', 'student4454'],
#   ['student3624', 'student9128'],
#   ['student6216', 'student2417'],
#   ['student5068', 'student2468'],
#   ['student6792', 'student4134', 'student3677'],
#   ['student1080'],
#   ['student5482', 'student9486', 'student5494'],
#   ['student8172', 'student6900', 'student1889'],
#   ['student7700', 'student4096'],
#   ['student4152'],
#   ['student9073', 'student8853'],
#   ['student6121', 'student4640'],
#   ['student6018'],
#   ['student6374', 'student6915'],
#   ['student9531', 'student1093'],
#   ['student9547', 'student8815'],
#   ['student1845', 'student7090'],
#   ['student7582', 'student9542'],
#   ['student4749'],
#   ['student1600']],
#  'A2017/Z1/Z3': [['student5005'],
#   ['student8486'],
#   ['student7709', 'student6471'],
#   ['student5622'],
#   ['student8011', 'student9981'],
#   ['student5374', 'student9705', 'student3871'],
#   ['student5383', 'student8142'],
#   ['student3624'],
#   ['student8566'],
#   ['student6216', 'student2417'],
#   ['student1640'],
#   ['student7043', 'student5816', 'student3836'],
#   ['student3866'],
#   ['student6792', 'student4134'],
#   ['student7632'],
#   ['student1080'],
#   ['student1037', 'student9884'],
#   ['student1565'],
#   ['student3506', 'student2468', 'student4152'],
#   ['student1412', 'student1710'],
#   ['student5482', 'student9486', 'student5494'],
#   ['student6900', 'student1889'],
#   ['student6168', 'student1366'],
#   ['student1600']],
#  'A2017/Z1/Z4': [['student5005'],
#   ['student8486'],
#   ['student7709', 'student6471'],
#   ['student8011',
#    'student6609',
#    'student9964',
#    'student1565',
#    'student4454',
#    'student6723'],
#   ['student5374', 'student9705'],
#   ['student5383', 'student8142'],
#   ['student5220', 'student1704'],
#   ['student8566'],
#   ['student5816'],
#   ['student4265', 'student3836'],
#   ['student6582', 'student8522'],
#   ['student9155'],
#   ['student1080'],
#   ['student3506', 'student2468'],
#   ['student5482', 'student9486', 'student5494'],
#   ['student6900', 'student1889'],
#   ['student7700', 'student4577'],
#   ['student4152'],
#   ['student9073'],
#   ['student2950'],
#   ['student8157', 'student7495'],
#   ['student3732'],
#   ['student6369'],
#   ['student6168', 'student1366'],
#   ['student6635']],
#  'A2017/Z2/Z1': [['student3423', 'student6813'],
#   ['student7443', 'student9946'],
#   ['student3671', 'student9538', 'student6053', 'student3776'],
#   ['student7956'],
#   ['student6346', 'student7906', 'student1582'],
#   ['student6121', 'student4640'],
#   ['student8560', 'student6468'],
#   ['student1009', 'student6542'],
#   ['student1517', 'student7708'],
#   ['student4134', 'student5193', 'student8142', 'student5996'],
#   ['student5276', 'student7709', 'student2343'],
#   ['student6792', 'student3367'],
#   ['student5005'],
#   ['student4059', 'student7778'],
#   ['student1640'],
#   ['student8674'],
#   ['student5160'],
#   ['student3424'],
#   ['student3856'],
#   ['student6001'],
#   ['student1954'],
#   ['student9201'],
#   ['student1412'],
#   ['student9125'],
#   ['student7742'],
#   ['student9155'],
#   ['student3421'],
#   ['student2939'],
#   ['student9986'],
#   ['student5970'],
#   ['student8035']],
#  'A2017/Z2/Z2': [['student7708'],
#   ['student2870', 'student9705', 'student5996', 'student5861'],
#   ['student9155', 'student9547'],
#   ['student4740', 'student3866'],
#   ['student3856', 'student4554', 'student4100'],
#   ['student5005', 'student9671'],
#   ['student9946', 'student3421', 'student5789', 'student5673'],
#   ['student9824', 'student1068'],
#   ['student6018', 'student9538'],
#   ['student8859'],
#   ['student1704'],
#   ['student7936', 'student7582'],
#   ['student1009'],
#   ['student5160'],
#   ['student3776'],
#   ['student9201'],
#   ['student1412'],
#   ['student7742'],
#   ['student2939'],
#   ['student3732'],
#   ['student4370'],
#   ['student2417'],
#   ['student7514'],
#   ['student7778'],
#   ['student9986']],
#  'A2017/Z2/Z3': [['student5193', 'student8142', 'student5996'],
#   ['student6156', 'student9416'],
#   ['student9155', 'student9547'],
#   ['student4740', 'student3866'],
#   ['student6018', 'student9538'],
#   ['student4059', 'student7778'],
#   ['student5789', 'student5673'],
#   ['student6001', 'student9275'],
#   ['student9705', 'student2870'],
#   ['student1640'],
#   ['student8674'],
#   ['student1009'],
#   ['student5160'],
#   ['student3776'],
#   ['student6121', 'student4640'],
#   ['student8157'],
#   ['student9201'],
#   ['student1412'],
#   ['student4683'],
#   ['student5220'],
#   ['student7742'],
#   ['student2197'],
#   ['student3421'],
#   ['student4824'],
#   ['student2142'],
#   ['student2939'],
#   ['student2464'],
#   ['student2417'],
#   ['student9986'],
#   ['student9671'],
#   ['student5005'],
#   ['student3425']],
#  'A2017/Z2/Z4': [['student1517', 'student7708'],
#   ['student9155', 'student9547'],
#   ['student3677'],
#   ['student1704'],
#   ['student5005', 'student9671'],
#   ['student9221',
#    'student2417',
#    'student9538',
#    'student5612',
#    'student5193',
#    'student8142',
#    'student3871'],
#   ['student6011', 'student6369', 'student4640', 'student6121'],
#   ['student5861', 'student6900'],
#   ['student1640'],
#   ['student8674'],
#   ['student1009'],
#   ['student5160'],
#   ['student6170'],
#   ['student9201'],
#   ['student1412'],
#   ['student3421'],
#   ['student4824'],
#   ['student4059'],
#   ['student4370'],
#   ['student7709'],
#   ['student7514'],
#   ['student3857'],
#   ['student6795'],
#   ['student7778'],
#   ['student9986']],
#  'A2017/Z3/Z1': [['student3857', 'student3423'],
#   ['student7043', 'student5816'],
#   ['student5970',
#    'student1297',
#    'student5639',
#    'student8997',
#    'student8176',
#    'student6774',
#    'student4638'],
#   ['student5861', 'student1551'],
#   ['student8863', 'student7495'],
#   ['student9105', 'student5832', 'student1410'],
#   ['student5612', 'student9993'],
#   ['student2870', 'student9416', 'student6900'],
#   ['student6168', 'student1366'],
#   ['student5220', 'student2511'],
#   ['student4748', 'student6320'],
#   ['student1710', 'student9128'],
#   ['student5939', 'student6553'],
#   ['student3871', 'student4134'],
#   ['student1352', 'student2208'],
#   ['student7936', 'student1009', 'student9221'],
#   ['student3777', 'student5276'],
#   ['student4785', 'student6931'],
#   ['student4261', 'student4468'],
#   ['student7382', 'student7094'],
#   ['student7906'],
#   ['student1440'],
#   ['student8011'],
#   ['student6582'],
#   ['student8319'],
#   ['student6548'],
#   ['student9981'],
#   ['student7343'],
#   ['student6121'],
#   ['student9547'],
#   ['student2648'],
#   ['student3866'],
#   ['student2689'],
#   ['student9201'],
#   ['student9275'],
#   ['student4305'],
#   ['student6966'],
#   ['student8753'],
#   ['student6001'],
#   ['student3900'],
#   ['student8133'],
#   ['student3776'],
#   ['student1976'],
#   ['student5355'],
#   ['student1464']],
#  'A2017/Z3/Z2': [['student5193', 'student5816'],
#   ['student8863', 'student7495'],
#   ['student8959', 'student3677', 'student9705'],
#   ['student3777', 'student5276'],
#   ['student2503', 'student5005'],
#   ['student8142', 'student7769', 'student7094'],
#   ['student5287', 'student3857', 'student6310', 'student7709'],
#   ['student7369', 'student2343'],
#   ['student5639', 'student1297', 'student5970'],
#   ['student6168', 'student1366', 'student7906'],
#   ['student4770', 'student9113'],
#   ['student8176', 'student5348', 'student1093', 'student8853'],
#   ['student6813', 'student7582'],
#   ['student7985', 'student3943'],
#   ['student7343', 'student8815'],
#   ['student4785', 'student6931'],
#   ['student7778'],
#   ['student6548'],
#   ['student8011'],
#   ['student9981'],
#   ['student8319'],
#   ['student5861'],
#   ['student8997'],
#   ['student6121'],
#   ['student1352'],
#   ['student6369'],
#   ['student2648'],
#   ['student8566'],
#   ['student1213'],
#   ['student1600'],
#   ['student4134'],
#   ['student3866'],
#   ['student7742'],
#   ['student2689'],
#   ['student9201'],
#   ['student7936'],
#   ['student9221'],
#   ['student4096'],
#   ['student8753'],
#   ['student7673'],
#   ['student6001'],
#   ['student8794'],
#   ['student3900'],
#   ['student8133'],
#   ['student1976'],
#   ['student9569'],
#   ['student1464']],
#  'A2017/Z3/Z3': [['student5970', 'student4638', 'student5639', 'student6774'],
#   ['student8011'],
#   ['student8863', 'student7495'],
#   ['student8959', 'student3677'],
#   ['student2870', 'student5861'],
#   ['student8176', 'student1093', 'student8997', 'student5348'],
#   ['student1710', 'student9128'],
#   ['student7709', 'student3857'],
#   ['student3777', 'student5276'],
#   ['student4577', 'student6168'],
#   ['student4785', 'student6931'],
#   ['student3253', 'student8753'],
#   ['student6376', 'student1366'],
#   ['student1600', 'student8257'],
#   ['student9201', 'student4096'],
#   ['student9569'],
#   ['student7906'],
#   ['student7778'],
#   ['student8152'],
#   ['student8319'],
#   ['student1845'],
#   ['student6170'],
#   ['student9705'],
#   ['student6121'],
#   ['student7343'],
#   ['student2648'],
#   ['student4134'],
#   ['student3866'],
#   ['student2689'],
#   ['student7936'],
#   ['student9837'],
#   ['student6966'],
#   ['student9498'],
#   ['student5355'],
#   ['student6548'],
#   ['student1464'],
#   ['student8674']],
#  'A2017/Z3/Z4': [['student1583',
#    'student3857',
#    'student4577',
#    'student1366',
#    'student6168'],
#   ['student2503', 'student1297'],
#   ['student6877', 'student6121', 'student6369'],
#   ['student9705', 'student8959'],
#   ['student5832', 'student6795', 'student9105', 'student1410', 'student5861'],
#   ['student8176', 'student8997'],
#   ['student7936', 'student4785', 'student6931'],
#   ['student5287', 'student6195'],
#   ['student5789', 'student2035'],
#   ['student4772', 'student6813'],
#   ['student2208', 'student1352'],
#   ['student7778'],
#   ['student1600'],
#   ['student9993'],
#   ['student7633'],
#   ['student3866'],
#   ['student9201'],
#   ['student8753'],
#   ['student8794'],
#   ['student4370'],
#   ['student7495'],
#   ['student3776'],
#   ['student5355'],
#   ['student8319']],
#  'A2017/Z4/Z1': [['student7090', 'student5355'],
#   ['student8566'],
#   ['student4397', 'student5166', 'student4748'],
#   ['student6516'],
#   ['student1620', 'student1068'],
#   ['student5348', 'student1372'],
#   ['student2421'],
#   ['student1976'],
#   ['student7495'],
#   ['student4420'],
#   ['student9201'],
#   ['student3253'],
#   ['student4729'],
#   ['student4736'],
#   ['student1009'],
#   ['student3116'],
#   ['student8560'],
#   ['student4665'],
#   ['student4280'],
#   ['student8288'],
#   ['student7697']],
#  'A2017/Z4/Z2': [['student5355', 'student6795'],
#   ['student5348', 'student1372'],
#   ['student5832', 'student9105'],
#   ['student2351'],
#   ['student7090', 'student7742'],
#   ['student5287', 'student4305'],
#   ['student7495'],
#   ['student4420'],
#   ['student3677'],
#   ['student9201'],
#   ['student8133'],
#   ['student9837'],
#   ['student4736'],
#   ['student8089'],
#   ['student3116'],
#   ['student6170'],
#   ['student4665'],
#   ['student4280'],
#   ['student8288'],
#   ['student7697']],
#  'A2017/Z4/Z3': [['student5355', 'student8576'],
#   ['student4261', 'student9949'],
#   ['student7090', 'student7742'],
#   ['student5348', 'student1372'],
#   ['student4397', 'student5166'],
#   ['student3517', 'student7697'],
#   ['student9201', 'student5287', 'student9141'],
#   ['student6168', 'student1366'],
#   ['student1710', 'student9128'],
#   ['student3116', 'student1120'],
#   ['student4420'],
#   ['student6088'],
#   ['student9837'],
#   ['student6468'],
#   ['student4736'],
#   ['student8560'],
#   ['student4665'],
#   ['student8288']],
#  'A2017/Z4/Z4': [['student5348', 'student1372'],
#   ['student4420'],
#   ['student9201'],
#   ['student9105'],
#   ['student4370'],
#   ['student9275'],
#   ['student9837'],
#   ['student4305'],
#   ['student6468'],
#   ['student2351'],
#   ['student4736'],
#   ['student8631'],
#   ['student5166']],
#  'A2017/Z5/Z1': [],
#  'A2017/Z5/Z2': [],
#  'A2017/Z5/Z3': [],
#  'A2017/Z5/Z4': [['student8412'], ['student6369', 'student9569']]}

# %%
import numpy as np
import os
dataset = []
iter = 1
for key, value in directory_dict.items():
    path = os.path.join('/home/bhushan/Downloads/src/', key)
    if os.path.exists(path):
        print('iter - ', iter)
        plag_count = 0
        for names in value:
            if len(names) > 1:
                for i in range(len(names)):
                    for j in range(i + 1, len(names)):
                        if key[0] == 'A':
                            dataset.append([key + '/' + names[i] + '.c', key + '/' + names[j] + '.c', 1])
                        else:
                            dataset.append([key + '/' + names[i] + '.cpp', key + '/' + names[j] + '.cpp', 1])
                        plag_count += 1
        if key[0] == 'A':
            list_of_names = [name + '.c' for sublist in value for name in sublist]
        else:
            list_of_names = [name + '.cpp' for sublist in value for name in sublist]
        count = 0
        list_dir = os.listdir(path)
        while count != plag_count:
            name1, name2 = np.random.choice(list_dir, 2, replace=False)
            if name1 not in list_of_names and name2 not in list_of_names:
                dataset.append([key + '/' + name1, key + '/' + name2, 0])
                count += 1
        print(f"done {iter}")
        iter += 1
# Out:
# iter -  1
# done 1
# iter -  2
# done 2
# iter -  3
# done 3
# iter -  4
# done 4
# iter -  5
# done 5
# iter -  6
# done 6
# iter -  7
# done 7
# iter -  8
# done 8
# iter -  9
# done 9
# iter -  10
# done 10
# iter -  11
# done 11
# iter -  12
# done 12
# iter -  13
# done 13
# iter -  14
# done 14
# iter -  15
# done 15
# iter -  16
# done 16
# iter -  17
# done 17
# iter -  18
# done 18
# iter -  19
# done 19
# iter -  20
# done 20
# iter -  21
# done 21
# iter -  22
# done 22
# iter -  23
# done 23
# iter -  24
# done 24
# iter -  25
# done 25
# iter -  26
# done 26
# iter -  27
# done 27
# iter -  28
# done 28
# iter -  29
# done 29
# iter -  30
# done 30
# iter -  31
# done 31
# iter -  32
# done 32
# iter -  33
# done 33
# iter -  34
# done 34
# iter -  35
# done 35
# iter -  36
# done 36
# iter -  37
# done 37
# iter -  38
# done 38
# iter -  39
# done 39
# iter -  40
# done 40
# iter -  41
# done 41
# iter -  42
# done 42
# iter -  43
# done 43
# iter -  44
# done 44
# iter -  45
# done 45
# iter -  46
# done 46
# iter -  47
# done 47
# iter -  48
# done 48
# iter -  49
# done 49
# iter -  50
# done 50
# iter -  51
# done 51
# iter -  52
# done 52
# iter -  53
# done 53
# iter -  54
# done 54
# iter -  55
# done 55
# iter -  56
# done 56
# iter -  57
# done 57
# iter -  58
# done 58
# iter -  59
# done 59
# iter -  60
# done 60
# iter -  61
# done 61

# %%
len(dataset)
# Out:
# 2726

# %%
true_positives = 0
true_negatives = 0
false_positives = 0
false_negatives = 0
m_array  = np.arange(4, 16, 2)
n_array = np.arange(128, 512, 32)
thr_array = np.arange(0.2, 0.9, 0.05)
stats = []
iterator = 1
for m in m_array:
    for n in n_array:
        print("m - ", m, "n - ", n)
        for thr in thr_array:
            true_negatives = 0
            true_positives = 0
            false_negatives = 0
            false_positives = 0
            error = 0
            for data in dataset:
                file1 = data[0]
                file2 = data[1]
                plagiarism = data[2]
                try:
                    with open('/home/bhushan/Downloads/src/' + file1, "r") as f:
                        content1 = f.read()
                    with open('/home/bhushan/Downloads/src/' + file2, "r") as f:
                        content2 = f.read()
                except:
                    error += 1
                    # print(error)
                    continue
                simhash_similarity = simhash_simi(content1, content2, m, n)
                if simhash_similarity >= thr:
                    if plagiarism == 1:
                        true_positives += 1
                    else:
                        false_positives += 1
                else:
                    if plagiarism == 0:
                        true_negatives += 1
                    else:
                        false_negatives += 1
            precision = true_positives / (true_positives + false_positives) if true_positives + false_positives != 0 else 0
            recall = true_positives / (true_positives + false_negatives) if true_positives + false_negatives != 0 else 0
            f1_score = 2 * (precision * recall) / (precision + recall) if precision + recall != 0 else 0
            accuracy = (true_positives + true_negatives) / (true_positives + true_negatives + false_positives + false_negat
999999999, precision - 0.5416666666666666, recall - 0.019230769230769232, f1_score - 0.03714285714285714, accuracy - 0.503499079189687
# m - 14, n - 448, thr - 0.7, precision - 0.5319148936170213, recall - 0.01849112426035503, f1_score - 0.035739814152966405, accuracy - 0.5031307550644567
# m - 14, n - 448, thr - 0.7499999999999998, precision - 0.5319148936170213, recall - 0.01849112426035503, f1_score - 0.035739814152966405, accuracy - 0.5031307550644567
# m - 14, n - 448, thr - 0.7999999999999998, precision - 0.5319148936170213, recall - 0.01849112426035503, f1_score - 0.035739814152966405, accuracy - 0.5031307550644567
# m - 14, n - 448, thr - 0.8499999999999999, precision - 0.5319148936170213, recall - 0.01849112426035503, f1_score - 0.035739814152966405, accuracy - 0.5031307550644567
# m -  14 n -  480
# m - 14, n - 480, thr - 0.2, precision - 0.5967741935483871, recall - 0.027366863905325445, f1_score - 0.052333804809052344, accuracy - 0.5064456721915286
# m - 14, n - 480, thr - 0.25, precision - 0.576271186440678, recall - 0.02514792899408284, f1_score - 0.04819277108433735, accuracy - 0.505340699815838
# m - 14, n - 480, thr - 0.3, precision - 0.5636363636363636, recall - 0.022928994082840236, f1_score - 0.04406538734896944, accuracy - 0.5046040515653776
# m - 14, n - 480, thr - 0.35, precision - 0.5660377358490566, recall - 0.022189349112426034, f1_score - 0.042704626334519574, accuracy - 0.5046040515653776
# m - 14, n - 480, thr - 0.39999999999999997, precision - 0.5576923076923077, recall - 0.021449704142011833, f1_score - 0.04131054131054131, accuracy - 0.5042357274401473
# m - 14, n - 480, thr - 0.44999999999999996, precision - 0.5686274509803921, recall - 0.021449704142011833, f1_score - 0.0413399857448325, accuracy - 0.5046040515653776
# m - 14, n - 480, thr - 0.49999999999999994, precision - 0.56, recall - 0.020710059171597635, f1_score - 0.03994293865905849, accuracy - 0.5042357274401473
# m - 14, n - 480, thr - 0.5499999999999999, precision - 0.5510204081632653, recall - 0.019970414201183433, f1_score - 0.038543897216274096, accuracy - 0.5038674033149171
# m - 14, n - 480, thr - 0.5999999999999999, precision - 0.5416666666666666, recall - 0.019230769230769232, f1_score - 0.03714285714285714, accuracy - 0.503499079189687
# m - 14, n - 480, thr - 0.6499999999999999, precision - 0.5416666666666666, recall - 0.019230769230769232, f1_score - 0.03714285714285714, accuracy - 0.503499079189687
# m - 14, n - 480, thr - 0.7, precision - 0.5319148936170213, recall - 0.01849112426035503, f1_score - 0.035739814152966405, accuracy - 0.5031307550644567
# m - 14, n - 480, thr - 0.7499999999999998, precision - 0.5319148936170213, recall - 0.01849112426035503, f1_score - 0.035739814152966405, accuracy - 0.5031307550644567
# m - 14, n - 480, thr - 0.7999999999999998, precision - 0.5319148936170213, recall - 0.01849112426035503, f1_score - 0.035739814152966405, accuracy - 0.5031307550644567
# m - 14, n - 480, thr - 0.8499999999999999, precision - 0.5319148936170213, recall - 0.01849112426035503, f1_score - 0.035739814152966405, accuracy - 0.5031307550644567

# %%
stats
# Out:
# [[4,
#   128,
#   0.2,
#   0.8267857142857142,
#   0.34245562130177515,
#   0.48430962343096234,
#   0.6368324125230203],
#  [4,
#   128,
#   0.25,
#   0.8621794871794872,
#   0.1989644970414201,
#   0.32331730769230765,
#   0.5852670349907919],
#  [4,
#   128,
#   0.3,
#   0.8228571428571428,
#   0.10650887573964497,
#   0.18860510805500982,
#   0.543646408839779],
#  [4,
#   128,
#   0.35,
#   0.7685185185185185,
#   0.0613905325443787,
#   0.1136986301369863,
#   0.5233885819521179],
#  [4,
#   128,
#   0.39999999999999997,
#   0.7228915662650602,
#   0.04437869822485207,
#   0.08362369337979095,
#   0.5156537753222836],
#  [4,
#   128,
#   0.44999999999999996,
#   0.6944444444444444,
#   0.03698224852071006,
#   0.0702247191011236,
#   0.5123388581952117],
#  [4,
#   128,
#   0.49999999999999994,
#   0.6666666666666666,
#   0.03254437869822485,
#   0.062059238363892814,
#   0.5101289134438306],
#  [4,
#   128,
#   0.5499999999999999,
#   0.6451612903225806,
#   0.029585798816568046,
#   0.05657708628005657,
#   0.5086556169429097],
#  [4,
#   128,
#   0.5999999999999999,
#   0.6451612903225806,
#   0.029585798816568046,
#   0.05657708628005657,
#   0.5086556169429097],
#  [4,
#   128,
#   0.6499999999999999,
#   0.6271186440677966,
#   0.027366863905325445,
#   0.0524450744153083,
#   0.5075506445672191],
#  [4,
#   128,
#   0.7,
#   0.6140350877192983,
#   0.025887573964497042,
#   0.049680624556423,
#   0.5068139963167587],
#  [4,
#
for stat in stats:
    if best is None or stat[-1] > best[-1]:
        best = stat
print(best)
# Out:
# [4, 480, 0.2, 0.825531914893617, 0.43047337278106507, 0.565872630043753, 0.6710865561694291]

# %%
import pandas as pd
df_simhash1 = pd.DataFrame(stats, columns=["m", "n", "threshold", "precision", "recall", "f1_score", "accuracy"])

# %%
df_simhash1.to_csv("simhash_results1.csv", index=False)

# %% [markdown]
# ## Simhash 2

# %%
def shingle_document(document, shingle_size=4):
    """Create shingles from a document."""
    shingles = set()
    words = document.split()
    for i in range(len(words) - shingle_size + 1):
        shingle = ' '.join(words[i:i+shingle_size])
        shingles.add(hash(shingle))
    return shingles

def simhash(document, shingle_size=4, hash_size=64):
    """Calculate the SimHash value of a document."""
    shingles = shingle_document(document, shingle_size)
    v = [0] * hash_size
    for shingle in shingles:
        for i in range(hash_size):
            bit = (shingle >> i) & 1
            if bit == 1:
                v[i] += 1
            else:
                v[i] -= 1
    simhash = 0
    for i in range(hash_size):
        if v[i] >= 0:
            simhash |= 1 << i
    return simhash

def hamming_distance(simhash1, simhash2):
    """Calculate the Hamming distance between two SimHash values."""
    return bin(simhash1 ^ simhash2).count('1')

def similarity(document1, document2, m, n):
    """Calculate the similarity between two documents using SimHash."""
    simhash1 = simhash(document1, m, n)
    simhash2 = simhash(document2, m, n)
    distance = hamming_distance(simhash1, simhash2)
    max_distance = 64  # Max possible Hamming distance for 64-bit hashes
    return 1 - (distance / max_distance)

# %%
true_positives = 0
true_negatives = 0
false_positives = 0
false_negatives = 0
m_array  = np.arange(4, 16, 2)
n_array = np.arange(128, 512, 32)
thr_array = np.arange(0.2, 0.9, 0.05)
stats = []
iterator = 1
for m in m_array:
    for n in n_array:
        print("m - ", m, "n - ", n)
        for thr in thr_array:
            true_negatives = 0
            true_positives = 0
            false_negatives = 0
            false_positives = 0
            error = 0
            for data in dataset:
                file1 = data[0]
                file2 = data[1]
                plagiarism = data[2]
                try:
                    with open('/home/bhushan/Downloads/src/' + file1, "r") as f:
                        content1 = f.read()
                    with open('/home/bhushan/Downloads/src/' + file2, "r") as f:
                        content2 = f.read()
                except:
                    error += 1
                    # print(error)
                    continue
                simhash_similarity = similarity(content1, content2, m, n)
                if simhash_similarity >= thr:
                    if plagiarism == 1:
                        true_positives += 1
                    else:
                        false_positives += 1
                else:
                    if plagiarism == 0:
                        true_negatives += 1
                    else:
                        false_negatives += 1
            precision = true_positives / (true_positives + false_positives) if true_positives + false_positives != 0 else 0
            recall = true_positives / (true_positives + false_negatives) if true_positives + false_negatives != 0 else 0
            f1_score = 2 * (precision * recall) / (precision + recall) if precision + recall != 0 else 0
            accuracy = (true_positives + true_negatives) / (true_positives + true_negatives + false_positives + false_negatives) if true_positives + true_negatives + false_positives + false_negatives != 0 else 0
            print(f'm - {m}, n - {n}, thr - {thr}, precision - {precision}, recall - {recall}, f1_score - {f1_score}, accuracy - {accuracy}')
            stats.append([m, n, thr, precision, recall, f1_score, accuracy])
# Out:
# m -  4 n -  128
# m - 4, n - 128, thr - 0.2, precision - 0.5275537634408602, recall - 0.5806213017751479, f1_score - 0.5528169014084506, accuracy - 0.5322283609576427
# m - 4, n - 128, thr - 0.25, precision - 0.5275537634408602, recall - 0.5806213017751479, f1_score - 0.5528169014084506, accuracy - 0.5322283609576427
# m - 4, n - 128, thr - 0.3, precision - 0.5275537634408602, recall - 0.5806213017751479, f1_score - 0.5528169014084506, accuracy - 0.5322283609576427
# m - 4, n -
# m - 4, n - 224, thr - 0.5999999999999999, precision - 0.7051886792452831, recall - 0.22115384615384615, f1_score - 0.3367117117117117, accuracy - 0.5661141804788213
# m - 4, n - 224, thr - 0.6499999999999999, precision - 0.7873303167420814, recall - 0.128698224852071, f1_score - 0.22123331214240302, accuracy - 0.5488029465930019
# m - 4, n - 224, thr - 0.7, precision - 0.8071428571428572, recall - 0.08357988165680473, f1_score - 0.15147453083109919, accuracy - 0.5337016574585636
# m - 4, n - 224, thr - 0.7499999999999998, precision - 0.808695652173913, recall - 0.06878698224852071, f1_score - 0.12678936605316973, accuracy - 0.5281767955801105
# m - 4, n - 224, thr - 0.7999999999999998, precision - 0.7582417582417582, recall - 0.05103550295857988, f1_score - 0.09563409563409563, accuracy - 0.5193370165745856
# m - 4, n - 224, thr - 0.8499999999999999, precision - 0.7283950617283951, recall - 0.04363905325443787, f1_score - 0.08234473133286813, accuracy - 0.5156537753222836
# m -  4 n -  256
# m - 4, n - 256, thr - 0.2, precision - 0.5275537634408602, recall - 0.5806213017751479, f1_score - 0.5528169014084506, accuracy - 0.5322283609576427
# m - 4, n - 256, thr - 0.25, precision - 0.5275537634408602, recall - 0.5806213017751479, f1_score - 0.5528169014084506, accuracy - 0.5322283609576427
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[98], line 32
#      30     # print(error)
#      31     continue
# ---> 32 simhash_similarity = similarity(content1, content2, m, n)
#      33 if simhash_similarity >= thr:
#      34     if plagiarism == 1:
#
# Cell In[97], line 34, in similarity(document1, document2, m, n)
#      32 """Calculate the similarity between two documents using SimHash."""
#      33 simhash1 = simhash(document1, m, n)
# ---> 34 simhash2 = simhash(document2, m, n)
#      35 distance = hamming_distance(simhash1, simhash2)
#      36 max_distance = 64  # Max possible Hamming distance for 64-bit hashes
#
# Cell In[97], line 20, in simhash(document, shingle_size, hash_size)
#      18             v[i] += 1
#      19         else:
# ---> 20             v[i] -= 1
#      21 simhash = 0
#      22 for i in range(hash_size):
#
# KeyboardInterrupt:

# %%
hash('bhushan')
# Out:
# 5026394993408580015

# %%
# Out:
# 2673647468389508103

# %% [markdown]
# ## Gen sim

# %%
# %pip install scipy==1.10.1
from gensim import corpora, models, similarities
from gensim.similarities import Similarity
from gensim.utils import tokenize

# Sample programs as text documents
program1 = "print('Hello, world!')"
program2 = "print('Hi there!')"

# Preprocess the documents and create a dictionary
documents = [program1, program2]
texts = [list(tokenize(doc.lower())) for doc in documents]
dictionary = corpora.Dictionary(texts)

# Create TF-IDF model
corpus = [dictionary.doc2bow(text) for text in texts]
tfidf = models.TfidfModel(corpus)

# Transform documents to TF-IDF vectors
corpus_tfidf = tfidf[corpus]

# Create similarity index
index = similarities.MatrixSimilarity(corpus_tfidf)

# Calculate similarity between documents
similarity = index[tfidf[dictionary.doc2bow(list(tokenize(program2.lower())))]]
print("Similarity:", similarity)
# Out:
# ERROR: Ignored the following yanked versions: 1.11.0
# ERROR: Ignored the following versions that require a different python version: 1.10.0 Requires-Python <3.12,>=3.8; 1.10.0rc1 Requires-Python <3.12,>=3.8; 1.10.0rc2 Requires-Python <3.12,>=3.8; 1.10.1 Requires-Python <3.12,>=3.8; 1.6.2 Requires-Python >=3.7,<3.10; 1.6.3 Requires-Python >=3.7,<3.10; 1.7.0 Requires-Python >=3.7,<3.10; 1.7.1 Requires-Python >=3.7,<3.10; 1.7.2 Requires-Python >=3.7,<3.11; 1.7.3 Requires-Python >=3.7,<3.11; 1.8.0 Requires-Python >=3.8,<3.11; 1.8.0rc1 Requires-Python >=3.8,<3.11; 1.8.0rc2 Requires-Python >=3.8,<3.11; 1.8.0rc3 Requires-Python >=3.8,<3.11; 1.8.0rc4 Requires-Python >=3.8,<3.11; 1.8.1 Requires-Python >=3.8,<3.11; 1.9.0 Requires-Python >=3.8,<3.12; 1.9.0rc1 Requires-Python >=3.8,<3.12; 1.9.0rc2 Requires-Python >=3.8,<3.12; 1.9.0rc3 Requires-Python >=3.8,<3.12; 1.9.1 Requires-Python >=3.8,<3.12
# ERROR: Could not find a version that satisfies the requirement scipy==1.10.1 (from versions: 0.8.0, 0.9.0, 0.10.0, 0.10.1, 0.11.0, 0.12.0, 0.12.1, 0.13.0, 0.13.1, 0.13.2, 0.13.3, 0.14.0, 0.14.1, 0.15.0, 0.15.1, 0.16.0, 0.16.1, 0.17.0, 0.17.1, 0.18.0, 0.18.1, 0.19.0, 0.19.1, 1.0.0, 1.0.1, 1.1.0, 1.2.0, 1.2.1, 1.2.2, 1.2.3, 1.3.0, 1.3.1, 1.3.2, 1.3.3, 1.4.0, 1.4.1, 1.5.0, 1.5.1, 1.5.2, 1.5.3, 1.5.4, 1.6.0, 1.6.1, 1.9.2, 1.9.3, 1.11.0rc1, 1.11.0rc2, 1.11.1, 1.11.2, 1.11.3, 1.11.4, 1.12.0rc1, 1.12.0rc2, 1.12.0, 1.13.0rc1, 1.13.0)
# ERROR: No matching distribution found for scipy==1.10.1
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[104], line 2
#       1 get_ipython().run_line_magic('pip', 'install scipy==1.10.1')
# ----> 2 from gensim import corpora, models, similarities
#       3 from gensim.similarities import Similarity
#       4 from gensim.utils import tokenize
#
# File ~/anaconda3/envs/new/lib/python3.12/site-packages/gensim/__init__.py:11
#       7 __version__ = '4.3.2'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File ~/anaconda3/envs/new/lib/python3.12/site-packages/gensim/corpora/__init__.py:6
#       1 """
#       2 This package contains implementations of various streaming corpus I/O format.
#       3 """
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#       9 from .bleicorpus import BleiCorpus  # noqa:F401
#
# File ~/anaconda3/envs/new/lib/python3.12/site-packages/gensim/corpora/indexedcorpus.py:14
#      10 import logging
#      12 import numpy
# ---> 14 from gensim import interfaces, utils
#      16 logger = logging.getLogger(__name__)
#      19 class IndexedCorpus(interfaces.CorpusABC):
#
# File ~/anaconda3/envs/new/lib/python3.12/site-packages/gensim/interfaces.py:19
#       7 """Basic interfaces used across the whole Gensim package.
#       8
#       9 These interfaces are used for building corpora, model transformation and similarity queries.
#    (...)
#      14
#      15 """
#      17 import logging
# ---> 19 from gensim import utils, matutils
#      22 logger = logging.getLogger(__name__)
#      25 class CorpusABC(utils.SaveLoad):
#
# File ~/anaconda3/envs/new/lib/python3.12/site-packages/gensim/matutils.py:20
#      18 import scipy.sparse
#      19 from scipy.stats import entropy
# ---> 20 from scipy.linalg import get_blas_funcs, triu
#      21 from scipy.linalg.lapack import get_lapack_funcs
#      22 from scipy.special import psi  # gamma function utils
#
# ImportError: cannot import name 'triu' from 'scipy.linalg' (/home/bhushan/anaconda3/envs/new/lib/python3.12/site-packages/scipy/linalg/__init__.py)

# %% [markdown]
# ## TFIDF

# %%
# Out:
# Requirement already satisfied: scipy in /home/bhushan/anaconda3/envs/new/lib/python3.12/site-packages (1.13.0)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /home/bhushan/anaconda3/envs/new/lib/python3.12/site-packages (from scipy) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
progs = []
count = 0
for data in dataset:
    file1 = data[0]
    file2 = data[1]
    try:
        with open('/home/bhushan/Downloads/src/' + file1, "r") as f:
            content1 = f.read()
            progs.append(content1)
    except:
        print('file error')
        count += 1
    try:
        with open('/home/bhushan/Downloads/src/' + file2, "r") as f:
            content2 = f.read()
            progs.append(content2)
    except:
        print('file error')
        count += 1
# Out:
# file error
# file error
# file error
# file error
# file error
# file error
# file error
# file error
# file error
# file error
# file error

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(progs)

# %%
a = tfidf_vectorizer.transform([progs[0]]).toarray()

# %%
print(sum(a[0] != 0))
# Out:
# 78

# %%
tfidf_stats = []
for thr in thr_array:
    true_negatives = 0
    true_positives = 0
    false_negatives = 0
    false_positives = 0
    for data in dataset:
        file1 = data[0]
        file2 = data[1]
        plagiarism = data[2]
        try:
            with open('/home/bhushan/Downloads/src/' + file1, "r") as f:
                content1 = f.read()
                prog1 = tfidf_vectorizer.transform([content1]).toarray()[0]
            with open('/home/bhushan/Downloads/src/' + file2, "r") as f:
                content2 = f.read()
                prog2 = tfidf_vectorizer.transform([content2]).toarray()[0]
        except:
            error += 1
            print(error)
            continue
        similarity = cosine_similarity([prog1], [prog2])[0][0]
        if similarity >= thr:
            if plagiarism == 1:
                true_positives += 1
            else:
                false_positives += 1
        else:
            if plagiarism == 0:
                true_negatives += 1
            else:
                false_negatives += 1
    precision = true_positives / (true_positives + false_positives) if true_positives + false_positives != 0 else 0
    recall = true_positives / (true_positives + false_negatives) if true_positives + false_negatives != 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if precision + recall != 0 else 0
    accuracy = (true_positives + true_negatives) / (true_positives + true_negatives + false_positives + false_negatives) if (true_positives + true_negatives + false_positives + false_negatives) != 0 else 0
    tfidf_stats.append([thr, precision, recall, f1_score, accuracy])
# Out:
# 11254
# 11255
# 11256
# 11257
# 11258
# 11259
# 11260
# 11261
# 11262
# 11263
# 11264
# 11265
# 11266
# 11267
# 11268
# 11269
# 11270
# 11271
# 11272
# 11273
# 11274
# 11275
# 11276
# 11277
# 11278
# 11279
# 11280
# 11281
# 11282
# 11283
# 11284
# 11285
# 11286
# 11287
# 11288
# 11289
# 11290
# 11291
# 11292
# 11293
# 11294
# 11295
# 11296
# 11297
# 11298
# 11299
# 11300
# 11301
# 11302
# 11303
# 11304
# 11305
# 11306
# 11307
# 11308
# 11309
# 11310
# 11311
# 11312
# 11313
# 11314
# 11315
# 11316
# 11317
# 11318
# 11319
# 11320
# 11321
# 11322
# 11323
# 11324
# 11325
# 11326
# 11327
# 11328
# 11329
# 11330
# 11331
# 11332
# 11333
# 11334
# 11335
# 11336
# 11337
# 11338
# 11339
# 11340
# 11341
# 11342
# 11343
# 11344
# 11345
# 11346
# 11347
# 11348
# 11349
# 11350
# 11351
# 11352
# 11353
# 11354
# 11355
# 11356
# 11357
# 11358
# 11359
# 11360
# 11361
# 11362
# 11363
# 11364
# 11365
# 11366
# 11367
# 11368
# 11369
# 11370
# 11371
# 11372
# 11373
# 11374
# 11375
# 11376
# 11377
# 11378
# 11379
# 11380
# 11381
# 11382
# 11383
# 11384
# 11385
# 11386
# 11387
# 11388
# 11389
# 11390
# 11391
# 11392
# 11393
# 11394
# 11395
# 11396
# 11397
# 11398
# 11399
# 11400
# 11401
# 11402
# 11403
# 11404
# 11405
# 11406
# 11407

# %%
df_tfidf = pd.DataFrame(tfidf_stats, columns=["threshold", "precision", "recall", "f1_score", "accuracy"])

# %%
df_tfidf
# Out:
#     threshold  precision    recall  f1_score  accuracy
# 0        0.20   0.591859  0.817308  0.686549  0.628361
# 1        0.25   0.606974  0.759615  0.674770  0.635359
# 2        0.30   0.627968  0.704142  0.663877  0.644936
# 3        0.35   0.649635  0.658284  0.653931  0.653039
# 4        0.40   0.673339  0.622041  0.646674  0.661510
# 5        0.45   0.690090  0.566568  0.622258  0.657459
# 6        0.50   0.711089  0.517012  0.598715  0.654880
# 7        0.55   0.733260  0.494083  0.590367  0.658564
# 8        0.60   0.746394  0.459320  0.568681  0.653039
# 9        0.65   0.756972  0.421598  0.541568  0.644567
# 10       0.70   0.770349  0.392012  0.519608  0.639042
# 11       0.75   0.779221  0.355030  0.487805  0.628729
# 12       0.80   0.801085  0.327663  0.465092  0.624678
# 13       0.85   0.811715  0.286982  0.424044  0.611786

# %%
df_tfidf.to_csv("tfidf_results.csv", index=False)

# %%
for data in dataset:
    file1 = data[0]
    file2 = data[1]
    plagiarism = data[2]
    try:
        with open('/home/bhushan/Downloads/src/' + file1, "r") as f:
            content1 = f.read()
        with open('/home/bhushan/Downloads/src/' + file2, "r") as f:
            content2 = f.read()
    except:
        error += 1
        print(error)
        continue
    simhash_similarity = simhash_simi(content1, content2, m, n)
    if simhash_similarity >= 0.2:
        if plagiarism == 1:
            true_positives += 1
        else:
            false_positives += 1
    else:
        if plagiarism == 0:
            true_negatives += 1
        else:
            false_negatives += 1
precision = true_positives / (true_positives + false_positives) if true_positives + false_positives != 0 else 0
recall = true_positives / (true_positives + false_negatives) if true_positives + false_negatives != 0 else 0
f1_score = 2 * (precision * recall) / (precision + recall) if precision + recall != 0 else 0
accuracy = (true_positives + true_negatives) / (true_positives + true_negatives + false_positives + false_negatives) if true_positives + true_negatives + false_positives + false_negatives != 0 else 0
# Out:
# 11243
# 11244
# 11245
# 11246
# 11247
# 11248
# 11249
# 11250
# 11251
# 11252
# 11253

# %%
true_negatives
# Out:
# 1365449

# %%
thr_array
# Out:
# array([0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55, 0.6 , 0.65, 0.7 ,
#        0.75, 0.8 , 0.85])
